# %% [markdown]
# <a href="https://colab.research.google.com/github/pablohd10/clasificacion-maniobras-conduccion-/blob/main/MANIOBRA_STOPPING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![LogoUC3M](data:image/png;base64,...)
#
# # **PRACTICA 01 - APLICACIONES AVANZADAS DE LA IA**
# ---
# **GRUPO 10**
# *   Sergio Caño Amor (100429678)
# *   Eduardo Enrique Angulo Luna (100545176)
# *   Pablo Hidalgo Delgado (100451225)

# %% [markdown]
# ## **1. Introducción.**

# %% [markdown]
# El objetivo de esta práctica es, a partir del dataset entregado, seleccionar al menos 2 de las 5 maniobras de conducción y determinar qué secuencia de eventos (acciones atómicas) son características de dicha maniobra. En nuestro caso, decidimos utilizar las maniobras de Stopping y Overtaking que corresponden al frenado del vehículo y al adelantamiento a otro vehículo respectivamente. En este notebook, se analizará la maniobra de **Stopping**.
#
# **REDACTAR MEJOR**

# %% [markdown]
# ### **1.1 Planteamiento del problema**
# Para abordar esta práctica, decidimos desarrollar dos modelos de clasificación basados en **Random Forest** para predecir si un conjunto de datos corresponde a una maniobra específica, en función de las características del comportamiento del conductor. Estos modelos estarán diseñados para clasificar, por separado, las 2 maniobras que se mencionan en la introducción:
#
# - **Frenado del vehículo** (maniobra "Stopping")
#
# - **Adelantamiento** (maniobra "Overtaking").
#
# Al abordar el problema de forma separada para cada maniobra, podremos identificar cuáles son los atributos más relevantes en la toma de decisiones para cada tipo de maniobra.
#
# Dado que los datos son secuenciales, utilizaremos **ventanas temporales** para agrupar la información de instantes pasados en una única instancia, lo que permitirá capturar las dinámicas temporales de cada maniobra. Esta técnica de ventanas deslizantes facilitará que el modelo entienda mejor el contexto temporal de las maniobras, mejorando la precisión del modelo. Se analizará el impacto del tamaño de ventana, tanto solapadas como no solapadas de acuerdo a los resultados del modelo.
#
# Optamos por utilizar Random Forest como el modelo de clasificación debido a su eficiencia, capacidad de manejar datos no lineales y su explicabilidad. Estas características hacen que sea una opción adecuada para nuestro problema, ya que no solo proporcionará buenas predicciones, sino que también nos permitirá interpretar la **importancia de cada atributo** en la clasificación de las maniobras.

# %% [markdown]
# ## **2. Lectura de los datos.**

# %% [markdown]
# En primer lugar, importamos las librerías que necesitaremos a lo largo del proyecto:

# %%
import zipfile
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, precision_score, accuracy_score, f1_score, recall_score, confusion_matrix
from itertools import product

# %% [markdown]
# A continuación, descomprimimos el zip:

# %%
# Ruta al archivo .zip
zip_path = 'ManiobrasSimulador.zip'

extract_path = "./"  # Carpeta donde se extraerán los archivos

# Descomprimimos
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %% [markdown]
# Leemos los datos correspondientes a la **maniobra Stopping** y los concatenamos en un mismo dataframe de pandas. Añadimos una columna `Driver` que identifica al conductor. Esta columna nos servirá para poder dividir nuestros datos de entrenamiento, validación y test por conductor.

# %%
# Lista de archivos Excel maniobra Stopping
files_stopping = ['./ManiobrasSimulador/Driver1/STISIMData_Stopping.xlsx', './ManiobrasSimulador/Driver2/STISIMData_Stopping.xlsx', './ManiobrasSimulador/Driver3/STISIMData_Stopping.xlsx', './ManiobrasSimulador/Driver4/STISIMData_Stopping.xlsx', './ManiobrasSimulador/Driver5/STISIMData_Stopping.xlsx']

# Leemos y unimos los datasets
dataframes_stopping = []
for i, file in enumerate(files_stopping):
    df = pd.read_excel(file)
    df['Driver'] = i+1  # Añadimos columna de identificación del conductor
    dataframes_stopping.append(df)

# Concatenamos todos los datos en un único DataFrame
stopping_data = pd.concat(dataframes_stopping, ignore_index=True)

# %% [markdown]
# ### **2.2 Maniobra Overtaking**
# Leemos los datos correspondientes a la maniobra Overtaking y los concatenamos en un mismo dataframe de pandas. Añadimos una columna `Driver` que identifica al conductor.

# %%
# Lista de archivos Excel maniobra Overtaking
files_overtaking = ['./ManiobrasSimulador/Driver1/STISIMData_Overtaking.xlsx', './ManiobrasSimulador/Driver2/STISIMData_Overtaking.xlsx', './ManiobrasSimulador/Driver3/STISIMData_Overtaking.xlsx', './ManiobrasSimulador/Driver4/STISIMData_Overtaking.xlsx', './ManiobrasSimulador/Driver5/STISIMData_Overtaking.xlsx']

# Leemos y unimos los datasets
dataframes_overtaking = []
for i, file in enumerate(files_overtaking):
    df = pd.read_excel(file)
    df['Driver'] = i+1  # Añadimos columna de identificación del conductor
    dataframes_overtaking.append(df)

# Concatenamos todos los datos en un único DataFrame
overtaking_data = pd.concat(dataframes_overtaking, ignore_index=True)

# %% [markdown]
# ## **3. Análisis exploratorio de los datos.**
# Antes de empezar con la división en datos de entrenamiento y test, vamos a realizar un análisis exploratorio de datos (`EDA`). De esta manera, podremos investigar y resumir las características más importantes de nuestro conjunto de datos. Esto nos servirá para comprender mejor los datos y optimizar la obtención de nuestro modelo.

# %% [markdown]
# ### **3.1 Información básica**

# %%
stopping_data.info(memory_usage = 'deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59286 entries, 0 to 59285
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Elapsed time          59286 non-null  float64
#  1   Long Dist             59286 non-null  float64
#  2   Lat Pos               59286 non-null  float64
#  3   Steering wheel angle  59286 non-null  float64
#  4   Throttle input        59286 non-null  float64
#  5   Brake pedal force     59286 non-null  float64
#  6   Gas pedal             59286 non-null  int64
#  7   Brake pedal           59286 non-null  int64
#  8   Clutch pedal          59286 non-null  int64
#  9   Left turn             59286 non-null  int64
#  10  Right turn            59286 non-null  int64
#  11  Gear                  59286 non-null  int64
#  12  speed                 59286 non-null  float64
#  13  RPM                   59286 non-null  float64
#  14  Hand wheel torque     59286 non-null  float64
#  15  Maneuver marker flag  59286 non-null  int64
#  16  Accidents             5 non-null      float64
#  17  Collisions            5 non-null      float64
#  18  Peds Hit              5 non-null      float64
#  19  Speeding Tics         5 non-null      float64
#  20  Red Lgt Tics          5 non-null      float64
#  21  Speed Exceed          5 non-null      float64
#  22  Stop Sign Ticks       5 non-null      float64
#  23  Driver                59286 non-null  int64
# dtypes: float64(16), int64(8)
# memory usage: 10.9 MB

# %% [markdown]
# * El conjunto de datos se compone de **59286 instancias y 24 atributos**, algunos de tipo float64 y otros de tipo int64. La variable de salida, `Maneuver marker flag`, es de tipo int64 (0 si no se está produciendo la maniobra de Stopping y 1 si se está produciendo)
#
# * También podemos observar que existen 7 columnas que contienen valores nulos. Después de analizar su significado e impacto sobre la variable de salida, decidimos eliminarlas de nuestro dataset ya que no aportan información útil a la variable de respuesta.

# %%
stopping_data.drop(['Accidents', 'Collisions', 'Peds Hit', 'Speeding Tics', 'Red Lgt Tics', 'Speed Exceed', 'Stop Sign Ticks'], axis=1, inplace=True) # Hay muy pocos valores (solo 5) y no son relevantes para predecir el frenado del vehículo

# %% [markdown]
# ### **3.2 Atributos compuestos de valores constantes**
# A continuación, vamos a comprobar si existen columnas constantes en nuestro conjunto de datos. En ese caso, podremos eliminarlas de nuestro dataset ya que no aportan ninguna información a la variable de respuesta y no existe riesgo de information leakage.

# %%
# Obtenemos las columnas constantes
columnas_constantes = []
for col in stopping_data.columns:
    if stopping_data[col].nunique() == 1:
        print(col)
        columnas_constantes.append(col)
if len(columnas_constantes) == 0:
  print("No existen atributos con valores constantes")
# Out:
# Left turn
# Right turn

# %% [markdown]
# Las columnas `Left turn` y `Right turn` contienen valores constantes, lo que indica que no se están realizando giros durante el frenado. Dado que estas variables no aportan información relevante para nuestro poblema, las eliminamos del conjunto de datos.

# %%
stopping_data.drop(['Left turn', 'Right turn'], axis=1, inplace=True)

# %% [markdown]
# ### **3.3 Atributos correlados**

# %% [markdown]
# A continuación, vamos a estudiar la **correlación** entre los atributos de los datos disponibles. Nos interesa conocer el conjunto de atributos que tienen una correlación especialmente alta (`> 0.95`) entre ellos para así poder determinar cuáles aportan a la variable de respuesta una información extremadamente similar que su par y, en consecuencia, poder plantearnos descartar uno de ellos para reducir la dimensionalidad del problema.

# %%
# Matriz de correlación, sólo se muestran valores > 0.95 ó < -0.95
print("\nMatriz de correlación. Sólo se muestran valores > 0.95 ó < -0.95\n")

# Establecemos el valor máximo de filas a mostrar en 5 para que no ocupe demasiado espacio.
pd.set_option('display.max_rows', 5)

# Calculamos la matriz de correlación (correlación de Pearson)
corr_matrix = stopping_data.corr()

# Filtramos por los valores que tienen una correlación mayor a 0.95 o menor a -0.95
mask = ((corr_matrix > 0.95) & (corr_matrix < 1)) | ((corr_matrix < -0.95) & (corr_matrix > -1))

# Seleccionamos las columnas y filas que cumplen la condición
high_corr = corr_matrix[mask].dropna(how='all', axis=0).dropna(how='all', axis=1)

# Mostramos las columnas y filas seleccionadas
print(high_corr)

# FIGURA MATRIZ DIAGONAL DE CORRELACION
# Tapamos el triangulo de arriba ya que es innecesario
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

# Preparamos la figura de matplotlib
f, ax = plt.subplots(figsize=(20, 20))
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Dibujamos la figura
sns.heatmap(corr_matrix, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# Matriz de correlación. Sólo se muestran valores > 0.95 ó < -0.95
#
#               Elapsed time  Long Dist  Throttle input  Brake pedal force  \
# Elapsed time           NaN   0.997753             NaN                NaN
# Long Dist         0.997753        NaN             NaN                NaN
# ...                    ...        ...             ...                ...
# Gas pedal              NaN        NaN        0.999977                NaN
# Brake pedal            NaN        NaN             NaN                1.0
#
#               Gas pedal  Brake pedal
# Elapsed time        NaN          NaN
# Long Dist           NaN          NaN
# ...                 ...          ...
# Gas pedal           NaN          NaN
# Brake pedal         NaN          NaN
#
# [6 rows x 6 columns]
# <Axes: >

# %% [markdown]
# Después de analizar la matriz de correlación y los valores obtenidos, identificamos una alta correlación entre las siguientes variables:
#
# - **Long dist y Elapsed time**: Dado que el tiempo transcurrido está directamente relacionado con la distancia recorrida por el vehículo, es esperable que ambas variables presenten una fuerte correlación.
#
# - **Gas pedal y Throttle input**: El atributo `Gas pedal` es el pedal físico que el conductor presiona para controlar la potencia del motor, mientras que la columna `Throttle input` representa la señal enviada al cuerpo del acelerador para regular el flujo de aire, determinada por la posición del pedal. Esta relación inherente explica su alta correlación.
#
# - **Brake pedal y Brake pedal force**: De acuerdo con la descripción del enunciado, el atributo `Brake pedal force` mide la fuerza aplicada por el conductor sobre el pedal, mientras que la columna `Brake pedal` refleja la fuerza de frenado que ejerce el vehículo. En condiciones de pendiente, ambas variables podrían diferir, ya que se requeriría una mayor fuerza para lograr el mismo nivel de frenado. Sin embargo, dado que todas las simulaciones se realizaron en entornos sin pendiente (como se establece en el enunciado de la práctica), la relación entre estas variables es completamente lineal, y lo podemos ver claramente reflejado en la matriz de correlación.
#
# Dado que cada par de variables proporciona información redundante, podemos descartar una de ellas en cada caso sin perder información relevante para el modelo.

# %%
# ELIMINAMOS UNA COLUMNA DE CADA PAR
stopping_data.drop(['Long Dist'], axis=1, inplace=True)
stopping_data.drop(['Brake pedal force'], axis=1, inplace=True) #porque no hay pendiente entonces la fuerza que hace el conductor es la misma que el coche internamente
stopping_data.drop(['Throttle input'], axis=1, inplace=True) #muy correlado con gas pedal --> aportan información similar a la variable de respuesta

# %% [markdown]
# ### **3.4 Distribución de clases**

# %% [markdown]
# En esta sección, analizaremos la distribución de las muestras entre las dos clases posibles: si el vehículo está realizando la maniobra de adelantamiento o no. Para ello, contaremos la cantidad de muestras en cada clase y representaremos los resultados en un gráfico de barras. Este análisis nos permitirá identificar posibles desbalances en los datos que podrían afectar el rendimiento del modelo.

# %%
# Calculamos el recuento de muestras por clase y ordenamos por índice (las clases)
distribucion = stopping_data['Maneuver marker flag'].value_counts().sort_index()

# Creamos la gráfica de barras
distribucion.plot(kind='bar', color='skyblue')
print(distribucion)
plt.xlabel('Clases')
plt.ylabel('Número de Muestras')
plt.title('Número de Muestras por Clase')
plt.show()
# Out:
# Maneuver marker flag
# 0    43437
# 1    15849
# Name: count, dtype: int64

# %% [markdown]
# El análisis de la distribución de clases muestra un desbalance en los datos, ya que la cantidad de casos en los que no se realiza la maniobra es significativamente mayor que aquellos en los que sí se realiza:
#
# - Instantes de tiempo sin maniobra: **43.437**
# - Instantes de tiempo con maniobra: **15.849**
#
# Para abordar este desbalance, evaluaremos el impacto del hiperparámetro `class_weight='balanced'`, comparando su desempeño con el modelo sin este ajuste. De este modo, podremos determinar cuál opción ofrece mejores resultados en la clasificación. Además, evaluaremos, tendremos en cuenta y nos guiaremos por métricas adecuadas para problemas desbalanceados como la `precisión`, el `recall`, y el `f1-score`

# %% [markdown]
# ## **4. Preproceso de los datos.**
# Previamente a entrenar los modelos, debemos realizar una transformación de los datos para que puedan ser interpretados por el algoritmo de manera eficiente. Las transformaciones de datos que realizamos son las siguientes:

# %% [markdown]
# ### **4.1 División de datos en train y test**

# %% [markdown]
# Una vez explorado y analizado nuestro conjunto de datos, dividimos el dataset en conjuntos de `entrenamiento` (train) y `prueba` (test). Más tarde, al realizar la validación cruzada, dividiremos el conjunto de entrenamiento en train train y train validation.
#
# Decidimos dividir los datos de manera que los datos de entrenamiento se correspondan con los 4 primeros conductores, y los datos de test se correspondan con el conductor 5. De esta manera, podremos comprobar cómo el modelo se desempeña con datos de un conductor nunca visto antes.

# %%
train_stopping_data = stopping_data[stopping_data['Driver'].isin([1, 2, 3, 4])]
print("Dimensiones del conjunto de entrenamiento: ", train_stopping_data.shape)
test_stopping_data = stopping_data[stopping_data['Driver'] == 5]
print("Dimensiones del conjunto de prueba: ", test_stopping_data.shape)
# Out:
# Dimensiones del conjunto de entrenamiento:  (47735, 12)
# Dimensiones del conjunto de prueba:  (11551, 12)

# %% [markdown]
# ### **4.2 Normalización de los datos**
# Es importante normalizar para escalar las características a un mismo rango, evitando que algunas dominen sobre otras y mejorando la estabilidad y rendimiento.
#
# La normalización la realizamos durante la validación cruzada utilizando solo la información de los datos de entrenamiento en cada fold, evitando así el riesgo de `information leakage` y asegurando una evaluación más realista del modelo.

# %% [markdown]
# ### **4.3 Creación del conjunto de datos aplicando ventanas deslizantes**

# %% [markdown]
# Dado que nuestros datos tienen una **estructura temporal**, utilizamos **ventanas deslizantes** para capturar las dependencias a lo largo del tiempo y permitir que el modelo aprenda cómo los valores previos influyen en los posteriores. Para ello, transformamos los datos de manera que cada ventana se represente como una única fila, donde cada columna almacena los valores de un instante de tiempo dentro de la ventana. Esto proporciona al modelo un contexto más amplio de temporabilidad en lugar de evaluar instantes aislados.
#
# Además, para enriquecer la representación de los datos, calculamos **características agregadas** dentro de cada ventana, como la `media`, la `desviación estándar`, el `valor máximo` y el `mínimo` de cada atributo. Estas características ayudan a capturar patrones más complejos en la evolución de los datos.
#
# En cuanto a la variable de respuesta, definimos que una ventana se considera positiva (1, maniobra en curso) si al menos un instante dentro de ella tiene un 1 en la variable objetivo. Este criterio no solo contribuye a mitigar el problema del desbalance en los datos, sino que también permite que el modelo aprenda a detectar situaciones previas al inicio del frenado (aunque identificadas como frenado), lo que resulta fundamental para mejorar su capacidad predictiva.
#
# Para implementar este enfoque, desarrollamos la siguiente función que convierte los datos en ventanas deslizantes, permitiendo **ajustar** tanto la **duración de la ventana en segundos** como el **grado de solapamiento** entre ellas. De esta manera, logramos capturar mejor la dinámica temporal del problema y proporcionar al modelo una representación más completa de la secuencia de eventos.

# %%
def generate_sliding_windows(df, window_seconds, overlap_seconds):
    window_size = window_seconds * 20  # 20 filas por segundo
    step = (window_seconds - overlap_seconds) * 20  # Definimos paso según solapamiento

    feature_columns = df.columns.difference(['Driver', 'Maneuver marker flag'])
    windows = []

    for driver_id, driver_data in df.groupby('Driver'): # Para cada conductor
        driver_data = driver_data.reset_index(drop=True)

        for start in range(0, len(driver_data) - window_size + 1, step): # Se crea la ventana deslizante
            window = driver_data.iloc[start:start + window_size]
            features = {}

            # Extraemos las características de la ventana con referencia temporal
            for col in feature_columns:
                features[f'{col}_mean_{window_seconds}s'] = window[col].mean()
                features[f'{col}_std_{window_seconds}s'] = window[col].std()
                features[f'{col}_max_{window_seconds}s'] = window[col].max()
                features[f'{col}_min_{window_seconds}s'] = window[col].min()

                 # Creamos una columna separada por cada instante de tiempo dentro de la ventana
                for i, value in enumerate(window[col].values):
                    features[f'{col}_t{i}'] = value  # Se almacena el valor en una columna específica

            # Etiqueta de la ventana (1 si hay stopping en la ventana, 0 si no)
            features['Maneuver_marker'] = int(window['Maneuver marker flag'].max() > 0)
            features['Driver'] = driver_id  # Mantenemos el identificador del conductor

            windows.append(features)

    return pd.DataFrame(windows)

# %% [markdown]
# Generamos varios datasets con los datos correspondientes a las ventanas deslizantes con distintos valores de tamaño de ventana y solapamiento.
#
# **Ventanas sin solapamiento**
# - window_seconds = 10s , overlap_seconds = 0s
# - window_seconds = 5s , overlap_seconds = 0s
# - window_seconds = 3s , overlap_seconds = 0s
# - window_seconds = 1s , overlap_seconds = 0s
#
# **Ventanas solapadas**
# - window_seconds = 10s , overlap_seconds = 3s
# - window_seconds = 5s , overlap_seconds = 2s
# - window_seconds = 3s , overlap_seconds = 1s

# %%
# Ventanas sin solapamiento
train_stopping_data_window_10s = generate_sliding_windows(train_stopping_data, window_seconds=10, overlap_seconds=0)
train_stopping_data_window_5s = generate_sliding_windows(train_stopping_data, window_seconds=5, overlap_seconds=0)
train_stopping_data_window_3s = generate_sliding_windows(train_stopping_data, window_seconds=3, overlap_seconds=0)
train_stopping_data_window_1s = generate_sliding_windows(train_stopping_data, window_seconds=1, overlap_seconds=0)

# Ventanas solapadas
train_stopping_data_window_10s_overlapped = generate_sliding_windows(train_stopping_data, window_seconds=10, overlap_seconds=3)
train_stopping_data_window_5s_overlapped = generate_sliding_windows(train_stopping_data, window_seconds=5, overlap_seconds=2)
train_stopping_data_window_3s_overlapped = generate_sliding_windows(train_stopping_data, window_seconds=3, overlap_seconds=1)

# %%
# Imprimimos tamaños de los datasets
print("Tamaño de los datasets con ventanas sin solapamiento:")
print(f"Ventanas de 10 segundos: {train_stopping_data_window_10s.shape}")
print(f"Ventanas de 5 segundos: {train_stopping_data_window_5s.shape}")
print(f"Ventanas de 3 segundos: {train_stopping_data_window_3s.shape}")
print(f"Ventanas de 1 segundo: {train_stopping_data_window_1s.shape}")
print('\n')

print("Tamaño de los datasets con ventanas solapadas:")
print(f"Ventanas de 10 segundos (con solapamiento de 3 segundos): {train_stopping_data_window_10s_overlapped.shape}")
print(f"Ventanas de 5 segundos (con solapamiento de 2 segundos): {train_stopping_data_window_5s_overlapped.shape}")
print(f"Ventanas de 3 segundos (con solapamiento de 1 segundo): {train_stopping_data_window_3s_overlapped.shape}")
# Out:
# Tamaño de los datasets con ventanas sin solapamiento:
# Ventanas de 10 segundos: (236, 2042)
# Ventanas de 5 segundos: (475, 1042)
# Ventanas de 3 segundos: (794, 642)
# Ventanas de 1 segundo: (2385, 242)
#
#
# Tamaño de los datasets con ventanas solapadas:
# Ventanas de 10 segundos (con solapamiento de 3 segundos): (337, 2042)
# Ventanas de 5 segundos (con solapamiento de 2 segundos): (791, 1042)
# Ventanas de 3 segundos (con solapamiento de 1 segundo): (1190, 642)

# %% [markdown]
# A continuación, verificaremos las columnas que se están generando. Por ejemplo, utilizaremos el conjunto de datos con una ventana de 5 segundos y sin solapamiento.
#
# Dado que cada fila del conjunto de datos representa un intervalo de 0.05 segundos (1 segundo dividido en 20 filas), una ventana de 5 segundos correspondería a 100 filas (5 segundos * 20 filas/segundo). Por lo tanto, deberíamos tener un total de **100 columnas para cada atributo**, representando los diferentes instantes dentro de la ventana, además de las **características agregadas** como la media o el valor máximo de esa ventana

# %%
for col in train_stopping_data_window_5s.columns:
    print(col)
# Out:
# Brake pedal_mean_5s
# Brake pedal_std_5s
# Brake pedal_max_5s
# Brake pedal_min_5s
# Brake pedal_t0
# Brake pedal_t1
# Brake pedal_t2
# Brake pedal_t3
# Brake pedal_t4
# Brake pedal_t5
# Brake pedal_t6
# Brake pedal_t7
# Brake pedal_t8
# Brake pedal_t9
# Brake pedal_t10
# Brake pedal_t11
# Brake pedal_t12
# Brake pedal_t13
# Brake pedal_t14
# Brake pedal_t15
# Brake pedal_t16
# Brake pedal_t17
# Brake pedal_t18
# Brake pedal_t19
# Brake pedal_t20
# Brake pedal_t21
# Brake pedal_t22
# Brake pedal_t23
# Brake pedal_t24
# Brake pedal_t25
# Brake pedal_t26
# Brake pedal_t27
# Brake pedal_t28
# Brake pedal_t29
# Brake pedal_t30
# Brake pedal_t31
# Brake pedal_t32
# Brake pedal_t33
# Brake pedal_t34
# Brake pedal_t35
# Brake pedal_t36
# Brake pedal_t37
# Brake pedal_t38
# Brake pedal_t39
# Brake pedal_t40
# Brake pedal_t41
# Brake pedal_t42
# Brake pedal_t43
# Brake pedal_t44
# Brake pedal_t45
# Brake pedal_t46
# Brake pedal_t47
# Brake pedal_t48
# Brake pedal_t49
# Brake pedal_t50
# Brake pedal_t51
# Brake pedal_t52
# Brake pedal_t53
# Brake pedal_t54
# Brake pedal_t55
# Brake pedal_t56
# Brake pedal_t57
# Brake pedal_t58
# Brake pedal_t59
# Brake pedal_t60
# Brake pedal_t61
# Brake pedal_t62
# Brake pedal_t63
# Brake pedal_t64
# Brake pedal_t65
# Brake pedal_t66
# Brake pedal_t67
# Brake pedal_t68
# Brake pedal_t69
# Brake pedal_t70
# Brake pedal_t71
# Brake pedal_t72
# Brake pedal_t73
# Brake pedal_t74
# Brake pedal_t75
# Brake pedal_t76
# Brake pedal_t77
# Brake pedal_t78
# Brake pedal_t79
# Brake pedal_t80
# Brake pedal_t81
# Brake pedal_t82
# Brake pedal_t83
# Brake pedal_t84
# Brake pedal_t85
# Brake pedal_t86
# Brake pedal_t87
# Brake pedal_t88
# Brake pedal_t89
# Brake pedal_t90
# Brake pedal_t91
# Brake pedal_t92
# Brake pedal_t93
# Brake pedal_t94
# Brake pedal_t95
# Brake pedal_t96
# Brake pedal_t97
# Brake pedal_t98
# Brake pedal_t99
# Clutch pedal_mean_5s
# Clutch pedal_std_5s
# Clutch pedal_max_5s
# Clutch pedal_min_5s
# Clutch pedal_t0
# Clutch pedal_t1
# Clutch pedal_t2
# Clutch pedal_t3
# Clutch pedal_t4
# Clutch pedal_t5
# Clutch pedal_t6
# Clutch pedal_t7
# Clutch pedal_t8
# Clutch pedal_t9
# Clutch pedal_t10
# Clutch pedal_t11
# Clutch pedal_t12
# Clutch pedal_t13
# Clutch pedal_t14
# Clutch pedal_t15
# Clutch pedal_t16
# Clutch pedal_t17
# Clutch pedal_t18
# Clutch pedal_t19
# Clutch pedal_t20
# Clutch pedal_t21
# Clutch pedal_t22
# Clutch pedal_t23
# Clutch pedal_t24
# Clutch pedal_t25
# Clutch pedal_t26
# Clutch pedal_t27
# Clutch pedal_t28
# Clutch pedal_t29
# Clutch pedal_t30
# Clutch pedal_t31
# Clutch pedal_t32
# Clutch pedal_t33
# Clutch pedal_t34
# Clutch pedal_t35
# Clutch pedal_t36
# Clutch pedal_t37
# Clutch pedal_t38
# Clutch pedal_t39
# Clutch pedal_t40
# Clutch pedal_t41
# Clutch pedal_t42
# Clutch pedal_t43
# Clutch pedal_t44
# Clutch pedal_t45
# Clutch pedal_t46
# Clutch pedal_t47
# Clutch pedal_t48
# Clutch pedal_t49
# Clutch pedal_t50
# Clutch pedal_t51
# Clutch pedal_t52
# Clutch pedal_t53
# Clutch pedal_t54
# Clutch pedal_t55
# Clutch pedal_t56
# Clutch pedal_t57
# Clutch pedal_t58
# Clutch pedal_t59
# Clutch pedal_t60
# Clutch pedal_t61
# Clutch pedal_t62
# Clutch pedal_t63
# Clutch pedal_t64
# Clutch pedal_t65
# Clutch pedal_t66
# Clutch pedal_t67
# Clutch pedal_t68
# Clutch pedal_t69
# Clutch pedal_t70
# Clutch pedal_t71
# Clutch pedal_t72
# Clutch pedal_t73
# Clutch pedal_t74
# Clutch pedal_t75
# Clutch pedal_t76
# Clutch pedal_t77
# Clutch pedal_t78
# Clutch pedal_t79
# Clutch pedal_t80
# Clutch pedal_t81
# Clutch pedal_t82
# Clutch pedal_t83
# Clutch pedal_t84
# Clutch pedal_t85
# Clutch pedal_t86
# Clutch pedal_t87
# Clutch pedal_t88
# Clutch pedal_t89
# Clutch pedal_t90
# Clutch pedal_t91
# Clutch pedal_t92
# Clutch pedal_t93
# Clutch pedal_t94
# Clutch pedal_t95
# Clutch pedal_t96
# Clutch pedal_t97
# Clutch pedal_t98
# Clutch pedal_t99
# Elapsed time_mean_5s
# Elapsed time_std_5s
# Elapsed time_max_5s
# Elapsed time_min_5s
# Elapsed time_t0
# Elapsed time_t1
# Elapsed time_t2
# Elapsed time_t3
# Elapsed time_t4
# Elapsed time_t5
# Elapsed time_t6
# Elapsed time_t7
# Elapsed time_t8
# Elapsed time_t9
# Elapsed time_t10
# Elapsed time_t11
# Elapsed time_t12
# Elapsed time_t13
# Elapsed time_t14
# Elapsed time_t15
# Elapsed time_t16
# Elapsed time_t17
# Elapsed time_t18
# Elapsed time_t19
# Elapsed time_t20
# Elapsed time_t21
# Elapsed time_t22
# Elapsed time_t23
# Elapsed time_t24
# Elapsed time_t25
# Elapsed time_t26
# Elapsed time_t27
# Elapsed time_t28
# Elapsed time_t29
# Elapsed time_t30
# Elapsed time_t31
# Elapsed time_t32
# Elapsed time_t33
# Elapsed time_t34
# Elapsed time_t35
# Elapsed time_t36
# Elapsed time_t37
# Elapsed time_t38
# Elapsed time_t39
# Elapsed time_t40
# Elapsed time_t41
# Elapsed time_t42
# Elapsed time_t43
# Elapsed time_t44
# Elapsed time_t45
# Elapsed time_t46
# Elapsed time_t47
# Elapsed time_t48
# Elapsed time_t49
# Elapsed time_t50
# Elapsed time_t51
# Elapsed time_t52
# Elapsed time_t53
# Elapsed time_t54
# Elapsed time_t55
# Elapsed time_t56
# Elapsed time_t57
# Elapsed time_t58
# Elapsed time_t59
# Elapsed time_t60
# Elapsed time_t61
# Elapsed time_t62
# Elapsed time_t63
# Elapsed time_t64
# Elapsed time_t65
# Elapsed time_t66
# Elapsed time_t67
# Elapsed time_t68
# Elapsed time_t69
# Elapsed time_t70
# Elapsed time_t71
# Elapsed time_t72
# Elapsed time_t73
# Elapsed time_t74
# Elapsed time_t75
# Elapsed time_t76
# Elapsed time_t77
# Elapsed time_t78
# Elapsed time_t79
# Elapsed time_t80
# Elapsed time_t81
# Elapsed time_t82
# Elapsed time_t83
# Elapsed time_t84
# Elapsed time_t85
# Elapsed time_t86
# Elapsed time_t87
# Elapsed time_t88
# Elapsed time_t89
# Elapsed time_t90
# Elapsed time_t91
# Elapsed time_t92
# Elapsed time_t93
# Elapsed time_t94
# Elapsed time_t95
# Elapsed time_t96
# Elapsed time_t97
# Elapsed time_t98
# Elapsed time_t99
# Gas pedal_mean_5s
# Gas pedal_std_5s
# Gas pedal_max_5s
# Gas pedal_min_5s
# Gas pedal_t0
# Gas pedal_t1
# Gas pedal_t2
# Gas pedal_t3
# Gas pedal_t4
# Gas pedal_t5
# Gas pedal_t6
# Gas pedal_t7
# Gas pedal_t8
# Gas pedal_t9
# Gas pedal_t10
# Gas pedal_t11
# Gas pedal_t12
# Gas pedal_t13
# Gas pedal_t14
# Gas pedal_t15
# Gas pedal_t16
# Gas pedal_t17
# Gas pedal_t18
# Gas pedal_t19
# Gas pedal_t20
# Gas pedal_t21
# Gas pedal_t22
# Gas pedal_t23
# Gas pedal_t24
# Gas pedal_t25
# Gas pedal_t26
# Gas pedal_t27
# Gas pedal_t28
# Gas pedal_t29
# Gas pedal_t30
# Gas pedal_t31
# Gas pedal_t32
# Gas pedal_t33
# Gas pedal_t34
# Gas pedal_t35
# Gas pedal_t36
# Gas pedal_t37
# Gas pedal_t38
# Gas pedal_t39
# Gas pedal_t40
# Gas pedal_t41
# Gas pedal_t42
# Gas pedal_t43
# Gas pedal_t44
# Gas pedal_t45
# Gas pedal_t46
# Gas pedal_t47
# Gas pedal_t48
# Gas pedal_t49
# Gas pedal_t50
# Gas pedal_t51
# Gas pedal_t52
# Gas pedal_t53
# Gas pedal_t54
# Gas pedal_t55
# Gas pedal_t56
# Gas pedal_t57
# Gas pedal_t58
# Gas pedal_t59
# Gas pedal_t60
# Gas pedal_t61
# Gas pedal_t62
# Gas pedal_t63
# Gas pedal_t64
# Gas pedal_t65
# Gas pedal_t66
# Gas pedal_t67
# Gas pedal_t68
# Gas pedal_t69
# Gas pedal_t70
# Gas pedal_t71
# Gas pedal_t72
# Gas pedal_t73
# Gas pedal_t74
# Gas pedal_t75
# Gas pedal_t76
# Gas pedal_t77
# Gas pedal_t78
# Gas pedal_t79
# Gas pedal_t80
# Gas pedal_t81
# Gas pedal_t82
# Gas pedal_t83
# Gas pedal_t84
# Gas pedal_t85
# Gas pedal_t86
# Gas pedal_t87
# Gas pedal_t88
# Gas pedal_t89
# Gas pedal_t90
# Gas pedal_t91
# Gas pedal_t92
# Gas pedal_t93
# Gas pedal_t94
# Gas pedal_t95
# Gas pedal_t96
# Gas pedal_t97
# Gas pedal_t98
# Gas pedal_t99
# Gear_mean_5s
# Gear_std_5s
# Gear_max_5s
# Gear_min_5s
# Gear_t0
# Gear_t1
# Gear_t2
# Gear_t3
# Gear_t4
# Gear_t5
# Gear_t6
# Gear_t7
# Gear_t8
# Gear_t9
# Gear_t10
# Gear_t11
# Gear_t12
# Gear_t13
# Gear_t14
# Gear_t15
# Gear_t16
# Gear_t17
# Gear_t18
# Gear_t19
# Gear_t20
# Gear_t21
# Gear_t22
# Gear_t23
# Gear_t24
# Gear_t25
# Gear_t26
# Gear_t27
# Gear_t28
# Gear_t29
# Gear_t30
# Gear_t31
# Gear_t32
# Gear_t33
# Gear_t34
# Gear_t35
# Gear_t36
# Gear_t37
# Gear_t38
# Gear_t39
# Gear_t40
# Gear_t41
# Gear_t42
# Gear_t43
# Gear_t44
# Gear_t45
# Gear_t46
# Gear_t47
# Gear_t48
# Gear_t49
# Gear_t50
# Gear_t51
# Gear_t52
# Gear_t53
# Gear_t54
# Gear_t55
# Gear_t56
# Gear_t57
# Gear_t58
# Gear_t59
# Gear_t60
# Gear_t61
# Gear_t62
# Gear_t63
# Gear_t64
# Gear_t65
# Gear_t66
# Gear_t67
# Gear_t68
# Gear_t69
# Gear_t70
# Gear_t71
# Gear_t72
# Gear_t73
# Gear_t74
# Gear_t75
# Gear_t76
# Gear_t77
# Gear_t78
# Gear_t79
# Gear_t80
# Gear_t81
# Gear_t82
# Gear_t83
# Gear_t84
# Gear_t85
# Gear_t86
# Gear_t87
# Gear_t88
# Gear_t89
# Gear_t90
# Gear_t91
# Gear_t92
# Gear_t93
# Gear_t94
# Gear_t95
# Gear_t96
# Gear_t97
# Gear_t98
# Gear_t99
# Hand wheel torque_mean_5s
# Hand wheel torque_std_5s
# Hand wheel torque_max_5s
# Hand wheel torque_min_5s
# Hand wheel torque_t0
# Hand wheel torque_t1
# Hand wheel torque_t2
# Hand wheel torque_t3
# Hand wheel torque_t4
# Hand wheel torque_t5
# Hand wheel torque_t6
# Hand wheel torque_t7
# Hand wheel torque_t8
# Hand wheel torque_t9
# Hand wheel torque_t10
# Hand wheel torque_t11
# Hand wheel torque_t12
# Hand wheel torque_t13
# Hand wheel torque_t14
# Hand wheel torque_t15
# Hand wheel torque_t16
# Hand wheel torque_t17
# Hand wheel torque_t18
# Hand wheel torque_t19
# Hand wheel torque_t20
# Hand wheel torque_t21
# Hand wheel torque_t22
# Hand wheel torque_t23
# Hand wheel torque_t24
# Hand wheel torque_t25
# Hand wheel torque_t26
# Hand wheel torque_t27
# Hand wheel torque_t28
# Hand wheel torque_t29
# Hand wheel torque_t30
# Hand wheel torque_t31
# Hand wheel torque_t32
# Hand wheel torque_t33
# Hand wheel torque_t34
# Hand wheel torque_t35
# Hand wheel torque_t36
# Hand wheel torque_t37
# Hand wheel torque_t38
# Hand wheel torque_t39
# Hand wheel torque_t40
# Hand wheel torque_t41
# Hand wheel torque_t42
# Hand wheel torque_t43
# Hand wheel torque_t44
# Hand wheel torque_t45
# Hand wheel torque_t46
# Hand wheel torque_t47
# Hand wheel torque_t48
# Hand wheel torque_t49
# Hand wheel torque_t50
# Hand wheel torque_t51
# Hand wheel torque_t52
# Hand wheel torque_t53
# Hand wheel torque_t54
# Hand wheel torque_t55
# Hand wheel torque_t56
# Hand wheel torque_t57
# Hand wheel torque_t58
# Hand wheel torque_t59
# Hand wheel torque_t60
# Hand wheel torque_t61
# Hand wheel torque_t62
# Hand wheel torque_t63
# Hand wheel torque_t64
# Hand wheel torque_t65
# Hand wheel torque_t66
# Hand wheel torque_t67
# Hand wheel torque_t68
# Hand wheel torque_t69
# Hand wheel torque_t70
# Hand wheel torque_t71
# Hand wheel torque_t72
# Hand wheel torque_t73
# Hand wheel torque_t74
# Hand wheel torque_t75
# Hand wheel torque_t76
# Hand wheel torque_t77
# Hand wheel torque_t78
# Hand wheel torque_t79
# Hand wheel torque_t80
# Hand wheel torque_t81
# Hand wheel torque_t82
# Hand wheel torque_t83
# Hand wheel torque_t84
# Hand wheel torque_t85
# Hand wheel torque_t86
# Hand wheel torque_t87
# Hand wheel torque_t88
# Hand wheel torque_t89
# Hand wheel torque_t90
# Hand wheel torque_t91
# Hand wheel torque_t92
# Hand wheel torque_t93
# Hand wheel torque_t94
# Hand wheel torque_t95
# Hand wheel torque_t96
# Hand wheel torque_t97
# Hand wheel torque_t98
# Hand wheel torque_t99
# Lat Pos_mean_5s
# Lat Pos_std_5s
# Lat Pos_max_5s
# Lat Pos_min_5s
# Lat Pos_t0
# Lat Pos_t1
# Lat Pos_t2
# Lat Pos_t3
# Lat Pos_t4
# Lat Pos_t5
# Lat Pos_t6
# Lat Pos_t7
# Lat Pos_t8
# Lat Pos_t9
# Lat Pos_t10
# Lat Pos_t11
# Lat Pos_t12
# Lat Pos_t13
# Lat Pos_t14
# Lat Pos_t15
# Lat Pos_t16
# Lat Pos_t17
# Lat Pos_t18
# Lat Pos_t19
# Lat Pos_t20
# Lat Pos_t21
# Lat Pos_t22
# Lat Pos_t23
# Lat Pos_t24
# Lat Pos_t25
# Lat Pos_t26
# Lat Pos_t27
# Lat Pos_t28
# Lat Pos_t29
# Lat Pos_t30
# Lat Pos_t31
# Lat Pos_t32
# Lat Pos_t33
# Lat Pos_t34
# Lat Pos_t35
# Lat Pos_t36
# Lat Pos_t37
# Lat Pos_t38
# Lat Pos_t39
# Lat Pos_t40
# Lat Pos_t41
# Lat Pos_t42
# Lat Pos_t43
# Lat Pos_t44
# Lat Pos_t45
# Lat Pos_t46
# Lat Pos_t47
# Lat Pos_t48
# Lat Pos_t49
# Lat Pos_t50
# Lat Pos_t51
# Lat Pos_t52
# Lat Pos_t53
# Lat Pos_t54
# Lat Pos_t55
# Lat Pos_t56
# Lat Pos_t57
# Lat Pos_t58
# Lat Pos_t59
# Lat Pos_t60
# Lat Pos_t61
# Lat Pos_t62
# Lat Pos_t63
# Lat Pos_t64
# Lat Pos_t65
# Lat Pos_t66
# Lat Pos_t67
# Lat Pos_t68
# Lat Pos_t69
# Lat Pos_t70
# Lat Pos_t71
# Lat Pos_t72
# Lat Pos_t73
# Lat Pos_t74
# Lat Pos_t75
# Lat Pos_t76
# Lat Pos_t77
# Lat Pos_t78
# Lat Pos_t79
# Lat Pos_t80
# Lat Pos_t81
# Lat Pos_t82
# Lat Pos_t83
# Lat Pos_t84
# Lat Pos_t85
# Lat Pos_t86
# Lat Pos_t87
# Lat Pos_t88
# Lat Pos_t89
# Lat Pos_t90
# Lat Pos_t91
# Lat Pos_t92
# Lat Pos_t93
# Lat Pos_t94
# Lat Pos_t95
# Lat Pos_t96
# Lat Pos_t97
# Lat Pos_t98
# Lat Pos_t99
# RPM_mean_5s
# RPM_std_5s
# RPM_max_5s
# RPM_min_5s
# RPM_t0
# RPM_t1
# RPM_t2
# RPM_t3
# RPM_t4
# RPM_t5
# RPM_t6
# RPM_t7
# RPM_t8
# RPM_t9
# RPM_t10
# RPM_t11
# RPM_t12
# RPM_t13
# RPM_t14
# RPM_t15
# RPM_t16
# RPM_t17
# RPM_t18
# RPM_t19
# RPM_t20
# RPM_t21
# RPM_t22
# RPM_t23
# RPM_t24
# RPM_t25
# RPM_t26
# RPM_t27
# RPM_t28
# RPM_t29
# RPM_t30
# RPM_t31
# RPM_t32
# RPM_t33
# RPM_t34
# RPM_t35
# RPM_t36
# RPM_t37
# RPM_t38
# RPM_t39
# RPM_t40
# RPM_t41
# RPM_t42
# RPM_t43
# RPM_t44
# RPM_t45
# RPM_t46
# RPM_t47
# RPM_t48
# RPM_t49
# RPM_t50
# RPM_t51
# RPM_t52
# RPM_t53
# RPM_t54
# RPM_t55
# RPM_t56
# RPM_t57
# RPM_t58
# RPM_t59
# RPM_t60
# RPM_t61
# RPM_t62
# RPM_t63
# RPM_t64
# RPM_t65
# RPM_t66
# RPM_t67
# RPM_t68
# RPM_t69
# RPM_t70
# RPM_t71
# RPM_t72
# RPM_t73
# RPM_t74
# RPM_t75
# RPM_t76
# RPM_t77
# RPM_t78
# RPM_t79
# RPM_t80
# RPM_t81
# RPM_t82
# RPM_t83
# RPM_t84
# RPM_t85
# RPM_t86
# RPM_t87
# RPM_t88
# RPM_t89
# RPM_t90
# RPM_t91
# RPM_t92
# RPM_t93
# RPM_t94
# RPM_t95
# RPM_t96
# RPM_t97
# RPM_t98
# RPM_t99
# Steering wheel angle_mean_5s
# Steering wheel angle_std_5s
# Steering wheel angle_max_5s
# Steering wheel angle_min_5s
# Steering wheel angle_t0
# Steering wheel angle_t1
# Steering wheel angle_t2
# Steering wheel angle_t3
# Steering wheel angle_t4
# Steering wheel angle_t5
# Steering wheel angle_t6
# Steering wheel angle_t7
# Steering wheel angle_t8
# Steering wheel angle_t9
# Steering wheel angle_t10
# Steering wheel angle_t11
# Steering wheel angle_t12
# Steering wheel angle_t13
# Steering wheel angle_t14
# Steering wheel angle_t15
# Steering wheel angle_t16
# Steering wheel angle_t17
# Steering wheel angle_t18
# Steering wheel angle_t19
# Steering wheel angle_t20
# Steering wheel angle_t21
# Steering wheel angle_t22
# Steering wheel angle_t23
# Steering wheel angle_t24
# Steering wheel angle_t25
# Steering wheel angle_t26
# Steering wheel angle_t27
# Steering wheel angle_t28
# Steering wheel angle_t29
# Steering wheel angle_t30
# Steering wheel angle_t31
# Steering wheel angle_t32
# Steering wheel angle_t33
# Steering wheel angle_t34
# Steering wheel angle_t35
# Steering wheel angle_t36
# Steering wheel angle_t37
# Steering wheel angle_t38
# Steering wheel angle_t39
# Steering wheel angle_t40
# Steering wheel angle_t41
# Steering wheel angle_t42
# Steering wheel angle_t43
# Steering wheel angle_t44
# Steering wheel angle_t45
# Steering wheel angle_t46
# Steering wheel angle_t47
# Steering wheel angle_t48
# Steering wheel angle_t49
# Steering wheel angle_t50
# Steering wheel angle_t51
# Steering wheel angle_t52
# Steering wheel angle_t53
# Steering wheel angle_t54
# Steering wheel angle_t55
# Steering wheel angle_t56
# Steering wheel angle_t57
# Steering wheel angle_t58
# Steering wheel angle_t59
# Steering wheel angle_t60
# Steering wheel angle_t61
# Steering wheel angle_t62
# Steering wheel angle_t63
# Steering wheel angle_t64
# Steering wheel angle_t65
# Steering wheel angle_t66
# Steering wheel angle_t67
# Steering wheel angle_t68
# Steering wheel angle_t69
# Steering wheel angle_t70
# Steering wheel angle_t71
# Steering wheel angle_t72
# Steering wheel angle_t73
# Steering wheel angle_t74
# Steering wheel angle_t75
# Steering wheel angle_t76
# Steering wheel angle_t77
# Steering wheel angle_t78
# Steering wheel angle_t79
# Steering wheel angle_t80
# Steering wheel angle_t81
# Steering wheel angle_t82
# Steering wheel angle_t83
# Steering wheel angle_t84
# Steering wheel angle_t85
# Steering wheel angle_t86
# Steering wheel angle_t87
# Steering wheel angle_t88
# Steering wheel angle_t89
# Steering wheel angle_t90
# Steering wheel angle_t91
# Steering wheel angle_t92
# Steering wheel angle_t93
# Steering wheel angle_t94
# Steering wheel angle_t95
# Steering wheel angle_t96
# Steering wheel angle_t97
# Steering wheel angle_t98
# Steering wheel angle_t99
# speed_mean_5s
# speed_std_5s
# speed_max_5s
# speed_min_5s
# speed_t0
# speed_t1
# speed_t2
# speed_t3
# speed_t4
# speed_t5
# speed_t6
# speed_t7
# speed_t8
# speed_t9
# speed_t10
# speed_t11
# speed_t12
# speed_t13
# speed_t14
# speed_t15
# speed_t16
# speed_t17
# speed_t18
# speed_t19
# speed_t20
# speed_t21
# speed_t22
# speed_t23
# speed_t24
# speed_t25
# speed_t26
# speed_t27
# speed_t28
# speed_t29
# speed_t30
# speed_t31
# speed_t32
# speed_t33
# speed_t34
# speed_t35
# speed_t36
# speed_t37
# speed_t38
# speed_t39
# speed_t40
# speed_t41
# speed_t42
# speed_t43
# speed_t44
# speed_t45
# speed_t46
# speed_t47
# speed_t48
# speed_t49
# speed_t50
# speed_t51
# speed_t52
# speed_t53
# speed_t54
# speed_t55
# speed_t56
# speed_t57
# speed_t58
# speed_t59
# speed_t60
# speed_t61
# speed_t62
# speed_t63
# speed_t64
# speed_t65
# speed_t66
# speed_t67
# speed_t68
# speed_t69
# speed_t70
# speed_t71
# speed_t72
# speed_t73
# speed_t74
# speed_t75
# speed_t76
# speed_t77
# speed_t78
# speed_t79
# speed_t80
# speed_t81
# speed_t82
# speed_t83
# speed_t84
# speed_t85
# speed_t86
# speed_t87
# speed_t88
# speed_t89
# speed_t90
# speed_t91
# speed_t92
# speed_t93
# speed_t94
# speed_t95
# speed_t96
# speed_t97
# speed_t98
# speed_t99
# Maneuver_marker
# Driver

# %% [markdown]
# ## **5. Validación cruzada y selección de hiperparámetros**

# %% [markdown]
# A continuación, exploraremos diversas combinaciones de hiperparámetros y aplicaremos **validación cruzada** para seleccionar la mejor configuración. La validación se llevará a cabo utilizando un esquema en el que el conjunto de entrenamiento se divide en `4 folds`, cada uno correspondiente a los datos de un conductor distinto. En cada iteración, el modelo se entrenará con los datos de 3 conductores y se evaluará con el conductor restante, asegurando así una evaluación más robusta y realista.
#
# Una vez realizados los `folds`, eliminamos el identificador del conductor para evitar que el modelo pueda hacer una asociación directa entre las características de conducción y el conductor específico, garantizando que el modelo generalice bien y no esté sesgado por las identidades de los conductores.
#
# Elegimos **RandomForest** como modelo debido a su explicabilidad, sencillez y porque creemos que se adecua perfectamente al propósito de nuestro problema.

# %%
# Fijamos una semilla aleatoria para reproducibilidad
np.random.seed(42)
random.seed(42)

# Lista de datasets a evaluar
datasets = {
    "window_10s": train_stopping_data_window_10s,
    "window_5s": train_stopping_data_window_5s,
    "window_3s": train_stopping_data_window_3s,
    "window_1s": train_stopping_data_window_1s,
    "window_10s_overlapped": train_stopping_data_window_10s_overlapped,
    "window_5s_overlapped": train_stopping_data_window_5s_overlapped,
    "window_3s_overlapped": train_stopping_data_window_3s_overlapped
}

# Definimos los hiperparámetros a probar
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'class_weight': [None, 'balanced']
}

# Genera todas las combinaciones de hiperparámetros
param_combinations = list(product(param_grid['n_estimators'], param_grid['max_depth'],
                                  param_grid['min_samples_split'], param_grid['min_samples_leaf'],
                                  param_grid['class_weight']))

# Diccionario para almacenar los mejores resultados por dataset
best_results = {}

# Iteramos sobre cada dataset
total_datasets = len(datasets)
for dataset_name, dataset in datasets.items():
    print(f'\nEvaluando dataset: {dataset_name}')

    best_score = 0
    best_params = None

    # Iteramos sobre cada combinación de hiperparámetros
    for params in param_combinations:
        n_estimators, max_depth, min_samples_split, min_samples_leaf, class_weight = params

        # Obtenemos la lista de conductores únicos del conjunto de entrenamiento
        drivers = dataset['Driver'].unique()

        # Almacenar métricas de validación cruzada
        fold_accuracies = []
        fold_precisions = []
        fold_recalls = []
        fold_f1s = []

        for test_driver in drivers:
            # Separamos datos en train y validación según el conductor
            train_data = dataset[dataset['Driver'] != test_driver]
            val_data = dataset[dataset['Driver'] == test_driver]

            # Separamos características y etiquetas
            X_train = train_data.drop(columns=['Maneuver_marker', 'Driver'])
            y_train = train_data['Maneuver_marker']
            X_val = val_data.drop(columns=['Maneuver_marker', 'Driver'])
            y_val = val_data['Maneuver_marker']

            # Normalizamos SOLO con datos de entrenamiento
            scaler = MinMaxScaler()
            X_train = scaler.fit_transform(X_train)
            X_val = scaler.transform(X_val)

            # Entrenamos el modelo con los hiperparámetros actuales
            model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth,
                                           min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf,
                                           class_weight=class_weight)
            model.fit(X_train, y_train)

            # Realizamos predicciones
            y_pred = model.predict(X_val)

            # Calculamos métricas
            fold_accuracies.append(accuracy_score(y_val, y_pred))
            fold_precisions.append(precision_score(y_val, y_pred, average=None))  # Por clase
            fold_recalls.append(recall_score(y_val, y_pred, average=None))
            fold_f1s.append(f1_score(y_val, y_pred, average=None))

        # Promediamos las métricas de cada fold
        mean_accuracy = np.mean(fold_accuracies)
        mean_precision = np.mean(fold_precisions, axis=0)  # Promedio por clase
        mean_recall = np.mean(fold_recalls, axis=0)
        mean_f1 = np.mean(fold_f1s, axis=0)

        print(f'\nHiperparámetros: {params}')
        print(f'Accuracy: {mean_accuracy:.4f}, '
              f'Precisión por clase: {mean_precision}, '
              f'Recall por clase: {mean_recall}, '
              f'F1 por clase: {mean_f1}')

        # Guardamos el mejor modelo basado en F1-score promedio
        if np.mean(mean_f1) > best_score:
            best_score = np.mean(mean_f1)  # Usamos el promedio de F1 por clase
            best_params = params

    # Almacenamos el mejor resultado para este dataset
    best_results[dataset_name] = {'best_params': best_params, 'best_score': best_score}
    print(f'\nMejores hiperparámetros para {dataset_name}: {best_params}, Mejor F1 promedio: {best_score:.4f}')

# Mostramos el resumen final de los mejores hiperparámetros por dataset
print('\nResumen de los mejores hiperparámetros por dataset:')
for dataset_name, result in best_results.items():
    print(f'{dataset_name}: {result}')
# Out:
# Evaluando dataset: window_10s
#
# Hiperparámetros: (50, None, 2, 1, None)
# Accuracy: 0.8398, Precisión por clase: [0.80005787 0.88793233], Recall por clase: [0.86240148 0.82135021], F1 por clase: [0.82606856 0.84999612]
#
# Hiperparámetros: (50, None, 2, 1, 'balanced')
# Accuracy: 0.8441, Precisión por clase: [0.83913987 0.85599817], Recall por clase: [0.81791872 0.8685217 ], F1 por clase: [0.82409502 0.85931621]
#
# Hiperparámetros: (50, None, 2, 2, None)
# Accuracy: 0.8656, Precisión por clase: [0.82514934 0.90683269], Recall por clase: [0.89025862 0.84549929], F1 por clase: [0.85524476 0.87404399]
#
# Hiperparámetros: (50, None, 2, 2, 'balanced')
# Accuracy: 0.8610, Precisión por clase: [0.83012821 0.89293608], Recall por clase: [0.87163793 0.85285223], F1 por clase: [0.84865152 0.87101554]
#
# Hiperparámetros: (50, None, 5, 1, None)
# Accuracy: 0.8402, Precisión por clase: [0.81808608 0.87373328], Recall por clase: [0.83592365 0.84458017], F1 por clase: [0.82002096 0.85406001]
#
# Hiperparámetros: (50, None, 5, 1, 'balanced')
# Accuracy: 0.8486, Precisión por clase: [0.81878868 0.87739375], Recall por clase: [0.85270936 0.84549929], F1 por clase: [0.83417341 0.86020036]
#
# Hiperparámetros: (50, None, 5, 2, None)
# Accuracy: 0.8403, Precisión por clase: [0.82139002 0.8697625 ], Recall por clase: [0.82699507 0.85264469], F1 por clase: [0.81662877 0.85643405]
#
# Hiperparámetros: (50, None, 5, 2, 'balanced')
# Accuracy: 0.8486, Precisión por clase: [0.80787989 0.89258768], Recall por clase: [0.87270936 0.82987429], F1 por clase: [0.83679101 0.85814019]
#
# Hiperparámetros: (50, 10, 2, 1, None)
# Accuracy: 0.8568, Precisión por clase: [0.82784163 0.88749314], Recall por clase: [0.86270936 0.85310425], F1 por clase: [0.84253746 0.86811272]
#
# Hiperparámetros: (50, 10, 2, 1, 'balanced')
# Accuracy: 0.8652, Precisión por clase: [0.83210496 0.898236  ], Recall por clase: [0.8805665 0.8535638], F1 por clase: [0.8544346  0.87425001]
#
# Hiperparámetros: (50, 10, 2, 2, None)
# Accuracy: 0.8699, Precisión por clase: [0.851341   0.89004768], Recall por clase: [0.86408867 0.87679376], F1 por clase: [0.8552696 0.8815943]
#
# Hiperparámetros: (50, 10, 2, 2, 'balanced')
# Accuracy: 0.8442, Precisión por clase: [0.82467934 0.86867409], Recall por clase: [0.8351601  0.85310425], F1 por clase: [0.82627627 0.85787835]
#
# Hiperparámetros: (50, 10, 5, 1, None)
# Accuracy: 0.8564, Precisión por clase: [0.83660969 0.87837379], Recall por clase: [0.85301724 0.86116876], F1 por clase: [0.84243591 0.86779199]
#
# Hiperparámetros: (50, 10, 5, 1, 'balanced')
# Accuracy: 0.8614, Precisión por clase: [0.83148975 0.89802928], Recall por clase: [0.87408867 0.85310425], F1 por clase: [0.84842958 0.87155227]
#
# Hiperparámetros: (50, 10, 5, 2, None)
# Accuracy: 0.8573, Precisión por clase: [0.82035714 0.89602188], Recall por clase: [0.87240148 0.8457513 ], F1 por clase: [0.84322179 0.86834175]
#
# Hiperparámetros: (50, 10, 5, 2, 'balanced')
# Accuracy: 0.8401, Precisión por clase: [0.81152618 0.87043818], Recall por clase: [0.84546798 0.83697521], F1 por clase: [0.82582055 0.85157363]
#
# Hiperparámetros: (50, 20, 2, 1, None)
# Accuracy: 0.8568, Precisión por clase: [0.82282878 0.89489563], Recall por clase: [0.87133005 0.84503973], F1 por clase: [0.84365123 0.86696482]
#
# Hiperparámetros: (50, 20, 2, 1, 'balanced')
# Accuracy: 0.8572, Precisión por clase: [0.83518519 0.88214123], Recall por clase: [0.85546798 0.86091675], F1 por clase: [0.84230062 0.86912079]
#
# Hiperparámetros: (50, 20, 2, 2, None)
# Accuracy: 0.8485, Precisión por clase: [0.82094451 0.88319286], Recall por clase: [0.8551601  0.84458017], F1 por clase: [0.8330586 0.8600501]
#
# Hiperparámetros: (50, 20, 2, 2, 'balanced')
# Accuracy: 0.8404, Precisión por clase: [0.81625626 0.86983044], Recall por clase: [0.83623153 0.84503973], F1 por clase: [0.82195982 0.85411154]
#
# Hiperparámetros: (50, 20, 5, 1, None)
# Accuracy: 0.8615, Precisión por clase: [0.83409362 0.89042597], Recall por clase: [0.86240148 0.86066473], F1 por clase: [0.8456008  0.87361111]
#
# Hiperparámetros: (50, 20, 5, 1, 'balanced')
# Accuracy: 0.8482, Precisión por clase: [0.82641941 0.87198388], Recall por clase: [0.84408867 0.85310425], F1 por clase: [0.83275467 0.8605342 ]
#
# Hiperparámetros: (50, 20, 5, 2, None)
# Accuracy: 0.8607, Precisión por clase: [0.83001071 0.89520153], Recall por clase: [0.87133005 0.85335626], F1 por clase: [0.84726204 0.8713555 ]
#
# Hiperparámetros: (50, 20, 5, 2, 'balanced')
# Accuracy: 0.8613, Precisión por clase: [0.83681354 0.88918443], Recall por clase: [0.86408867 0.86020517], F1 por clase: [0.8471606 0.8722207]
#
# Hiperparámetros: (100, None, 2, 1, None)
# Accuracy: 0.8695, Precisión por clase: [0.83811576 0.90331628], Recall por clase: [0.88133005 0.86116876], F1 por clase: [0.85660082 0.87974678]
#
# Hiperparámetros: (100, None, 2, 1, 'balanced')
# Accuracy: 0.8528, Precisión por clase: [0.81566033 0.89068512], Recall por clase: [0.87163793 0.83743477], F1 por clase: [0.84144385 0.86212642]
#
# Hiperparámetros: (100, None, 2, 2, None)
# Accuracy: 0.8694, Precisión por clase: [0.83359468 0.9121578 ], Recall por clase: [0.88995074 0.85239267], F1 por clase: [0.85725545 0.87847059]
#
# Hiperparámetros: (100, None, 2, 2, 'balanced')
# Accuracy: 0.8523, Precisión por clase: [0.8125     0.89739097], Recall por clase: [0.88194581 0.8301263 ], F1 por clase: [0.84323426 0.85994237]
#
# Hiperparámetros: (100, None, 5, 1, None)
# Accuracy: 0.8651, Precisión por clase: [0.83646232 0.89555765], Recall por clase: [0.87133005 0.86116876], F1 por clase: [0.85115815 0.87617724]
#
# Hiperparámetros: (100, None, 5, 1, 'balanced')
# Accuracy: 0.8528, Precisión por clase: [0.81467926 0.89201788], Recall por clase: [0.87133005 0.83768679], F1 por clase: [0.84042994 0.86267086]
#
# Hiperparámetros: (100, None, 5, 2, None)
# Accuracy: 0.8443, Precisión por clase: [0.81317639 0.88080209], Recall por clase: [0.85378079 0.8379388 ], F1 por clase: [0.8295958  0.85573809]
#
# Hiperparámetros: (100, None, 5, 2, 'balanced')
# Accuracy: 0.8528, Precisión por clase: [0.82749288 0.87988215], Recall por clase: [0.85408867 0.85381582], F1 por clase: [0.83811975 0.86464342]
#
# Hiperparámetros: (100, 10, 2, 1, None)
# Accuracy: 0.8482, Precisión por clase: [0.81565425 0.88600694], Recall por clase: [0.86270936 0.83819082], F1 por clase: [0.83532014 0.85842698]
#
# Hiperparámetros: (100, 10, 2, 1, 'balanced')
# Accuracy: 0.8777, Precisión por clase: [0.84649524 0.90853175], Recall por clase: [0.88887931 0.86898126], F1 por clase: [0.86584939 0.88732089]
#
# Hiperparámetros: (100, 10, 2, 2, None)
# Accuracy: 0.8613, Precisión por clase: [0.83657087 0.89106992], Recall por clase: [0.86378079 0.86116876], F1 por clase: [0.84620204 0.87287131]
#
# Hiperparámetros: (100, 10, 2, 2, 'balanced')
# Accuracy: 0.8608, Precisión por clase: [0.82496654 0.90033858], Recall por clase: [0.88163793 0.84529175], F1 por clase: [0.84984922 0.86977803]
#
# Hiperparámetros: (100, 10, 5, 1, None)
# Accuracy: 0.8571, Precisión por clase: [0.82180277 0.89375026], Recall por clase: [0.87270936 0.8457513 ], F1 por clase: [0.84448607 0.86745691]
#
# Hiperparámetros: (100, 10, 5, 1, 'balanced')
# Accuracy: 0.8564, Precisión por clase: [0.83445083 0.88031773], Recall por clase: [0.85270936 0.86045719], F1 por clase: [0.84094705 0.86854839]
#
# Hiperparámetros: (100, 10, 5, 2, None)
# Accuracy: 0.8571, Precisión por clase: [0.82784547 0.88925122], Recall por clase: [0.86240148 0.85381582], F1 por clase: [0.84197589 0.86879353]
#
# Hiperparámetros: (100, 10, 5, 2, 'balanced')
# Accuracy: 0.8697, Precisión por clase: [0.83796296 0.90335335], Recall por clase: [0.88133005 0.86091675], F1 por clase: [0.85682847 0.87987898]
#
# Hiperparámetros: (100, 20, 2, 1, None)
# Accuracy: 0.8529, Precisión por clase: [0.82435588 0.88497151], Recall por clase: [0.85347291 0.85310425], F1 por clase: [0.83500443 0.86621925]
#
# Hiperparámetros: (100, 20, 2, 1, 'balanced')
# Accuracy: 0.8528, Precisión por clase: [0.82014933 0.88599164], Recall por clase: [0.86270936 0.8457513 ], F1 por clase: [0.8390434  0.86388737]
#
# Hiperparámetros: (100, 20, 2, 2, None)
# Accuracy: 0.8402, Precisión por clase: [0.81046638 0.8733238 ], Recall por clase: [0.8451601 0.8379388], F1 por clase: [0.8243677 0.8526645]
#
# Hiperparámetros: (100, 20, 2, 2, 'balanced')
# Accuracy: 0.8612, Precisión por clase: [0.83567639 0.88829959], Recall por clase: [0.86270936 0.86091675], F1 por clase: [0.84668527 0.87259301]
#
# Hiperparámetros: (100, 20, 5, 1, None)
# Accuracy: 0.8486, Precisión por clase: [0.81828704 0.88153021], Recall por clase: [0.85378079 0.84503973], F1 por clase: [0.83275157 0.86078128]
#
# Hiperparámetros: (100, 20, 5, 1, 'balanced')
# Accuracy: 0.8656, Precisión por clase: [0.83710089 0.89582647], Recall por clase: [0.87270936 0.86091675], F1 por clase: [0.85215284 0.87617724]
#
# Hiperparámetros: (100, 20, 5, 2, None)
# Accuracy: 0.8486, Precisión por clase: [0.81255787 0.88867307], Recall por clase: [0.86240148 0.83697521], F1 por clase: [0.83372406 0.85980879]
#
# Hiperparámetros: (100, 20, 5, 2, 'balanced')
# Accuracy: 0.8487, Precisión por clase: [0.80664747 0.89509105], Recall por clase: [0.87240148 0.82987429], F1 por clase: [0.83551213 0.85901182]
#
# Hiperparámetros: (200, None, 2, 1, None)
# Accuracy: 0.8568, Precisión por clase: [0.82784163 0.88749314], Recall por clase: [0.86270936 0.85310425], F1 por clase: [0.84253746 0.86811272]
#
# Hiperparámetros: (200, None, 2, 1, 'balanced')
# Accuracy: 0.8442, Precisión por clase: [0.80622645 0.88482906], Recall por clase: [0.86270936 0.82987429], F1 por clase: [0.83134834 0.85457065]
#
# Hiperparámetros: (200, None, 2, 2, None)
# Accuracy: 0.8613, Precisión por clase: [0.8309619  0.89472489], Recall por clase: [0.87270936 0.85381582], F1 por clase: [0.84869492 0.87148242]
#
# Hiperparámetros: (200, None, 2, 2, 'balanced')
# Accuracy: 0.8613, Precisión por clase: [0.82381904 0.90149573], Recall por clase: [0.88133005 0.8457513 ], F1 por clase: [0.8494383  0.87083189]
#
# Hiperparámetros: (200, None, 5, 1, None)
# Accuracy: 0.8696, Precisión por clase: [0.84543423 0.89724895], Recall por clase: [0.87270936 0.86826969], F1 por clase: [0.85578129 0.88028522]
#
# Hiperparámetros: (200, None, 5, 1, 'balanced')
# Accuracy: 0.8650, Precisión por clase: [0.84417989 0.88967166], Recall por clase: [0.86270936 0.8685217 ], F1 por clase: [0.85009815 0.87657298]
#
# Hiperparámetros: (200, None, 5, 2, None)
# Accuracy: 0.8613, Precisión por clase: [0.82942802 0.89784076], Recall por clase: [0.87240148 0.85310425], F1 por clase: [0.84694543 0.87222078]
#
# Hiperparámetros: (200, None, 5, 2, 'balanced')
# Accuracy: 0.8612, Precisión por clase: [0.82949507 0.89525176], Recall por clase: [0.87270936 0.85310425], F1 por clase: [0.84798013 0.87168226]
#
# Hiperparámetros: (200, 10, 2, 1, None)
# Accuracy: 0.8528, Precisión por clase: [0.81618877 0.89380183], Recall por clase: [0.87270936 0.83697521], F1 por clase: [0.84078547 0.86221571]
#
# Hiperparámetros: (200, 10, 2, 1, 'balanced')
# Accuracy: 0.8612, Precisión por clase: [0.82949507 0.89525176], Recall por clase: [0.87270936 0.85310425], F1 por clase: [0.84798013 0.87168226]
#
# Hiperparámetros: (200, 10, 2, 2, None)
# Accuracy: 0.8530, Precisión por clase: [0.82087912 0.88669381], Recall por clase: [0.86408867 0.8457513 ], F1 por clase: [0.83964638 0.86387268]
#
# Hiperparámetros: (200, 10, 2, 2, 'balanced')
# Accuracy: 0.8612, Precisión por clase: [0.82949507 0.89525176], Recall por clase: [0.87270936 0.85310425], F1 por clase: [0.84798013 0.87168226]
#
# Hiperparámetros: (200, 10, 5, 1, None)
# Accuracy: 0.8652, Precisión por clase: [0.83782841 0.89667423], Recall por clase: [0.87270936 0.86045719], F1 por clase: [0.85160857 0.87579024]
#
# Hiperparámetros: (200, 10, 5, 1, 'balanced')
# Accuracy: 0.8568, Precisión por clase: [0.83656833 0.88183398], Recall por clase: [0.85408867 0.86116876], F1 por clase: [0.84186552 0.86852732]
#
# Hiperparámetros: (200, 10, 5, 2, None)
# Accuracy: 0.8528, Precisión por clase: [0.82153247 0.88644196], Recall por clase: [0.86270936 0.8457513 ], F1 por clase: [0.83929511 0.86354592]
#
# Hiperparámetros: (200, 10, 5, 2, 'balanced')
# Accuracy: 0.8526, Precisión por clase: [0.82691799 0.88043669], Recall por clase: [0.85408867 0.85310425], F1 por clase: [0.83769777 0.86452849]
#
# Hiperparámetros: (200, 20, 2, 1, None)
# Accuracy: 0.8697, Precisión por clase: [0.83796296 0.90335335], Recall por clase: [0.88133005 0.86091675], F1 por clase: [0.85682847 0.87987898]
#
# Hiperparámetros: (200, 20, 2, 1, 'balanced')
# Accuracy: 0.8528, Precisión por clase: [0.82014933 0.88599164], Recall por clase: [0.86270936 0.8457513 ], F1 por clase: [0.8390434  0.86388737]
#
# Hiperparámetros: (200, 20, 2, 2, None)
# Accuracy: 0.8613, Precisión por clase: [0.83598901 0.88755414], Recall por clase: [0.86270936 0.86162832], F1 por clase: [0.84712345 0.87271994]
#
# Hiperparámetros: (200, 20, 2, 2, 'balanced')
# Accuracy: 0.8653, Precisión por clase: [0.8375     0.89600781], Recall por clase: [0.87270936 0.86116876], F1 por clase: [0.85191237 0.87603454]
#
# Hiperparámetros: (200, 20, 5, 1, None)
# Accuracy: 0.8610, Precisión por clase: [0.8287037  0.89502002], Recall por clase: [0.87133005 0.85310425], F1 por clase: [0.84721308 0.87181447]
#
# Hiperparámetros: (200, 20, 5, 1, 'balanced')
# Accuracy: 0.8568, Precisión por clase: [0.82777094 0.88665388], Recall por clase: [0.86270936 0.85310425], F1 por clase: [0.84276127 0.86800995]
#
# Hiperparámetros: (200, 20, 5, 2, None)
# Accuracy: 0.8533, Precisión por clase: [0.83182942 0.87872151], Recall por clase: [0.84623153 0.86091675], F1 por clase: [0.8351045  0.86699779]
#
# Hiperparámetros: (200, 20, 5, 2, 'balanced')
# Accuracy: 0.8653, Precisión por clase: [0.83035714 0.90277864], Recall por clase: [0.88133005 0.85310425], F1 por clase: [0.85265575 0.87538401]
#
# Mejores hiperparámetros para window_10s: (100, 10, 2, 1, 'balanced'), Mejor F1 promedio: 0.8766
#
# Evaluando dataset: window_5s
#
# Hiperparámetros: (50, None, 2, 1, None)
# Accuracy: 0.9159, Precisión por clase: [0.90209185 0.94281669], Recall por clase: [0.96454064 0.8450146 ], F1 por clase: [0.93189195 0.89013908]
#
# Hiperparámetros: (50, None, 2, 1, 'balanced')
# Accuracy: 0.9056, Precisión por clase: [0.89007587 0.93509879], Recall por clase: [0.96095673 0.82373801], F1 por clase: [0.92397073 0.87532672]
#
# Hiperparámetros: (50, None, 2, 2, None)
# Accuracy: 0.9120, Precisión por clase: [0.90128522 0.93115751], Recall por clase: [0.9577376  0.84459741], F1 por clase: [0.92851008 0.88536227]
#
# Hiperparámetros: (50, None, 2, 2, 'balanced')
# Accuracy: 0.9099, Precisión por clase: [0.90386163 0.92132664], Recall por clase: [0.95063647 0.84991656], F1 por clase: [0.92644078 0.88357722]
#
# Hiperparámetros: (50, None, 5, 1, None)
# Accuracy: 0.9094, Precisión por clase: [0.89757885 0.93074222], Recall por clase: [0.95723398 0.83886108], F1 por clase: [0.92637913 0.88221725]
#
# Hiperparámetros: (50, None, 5, 1, 'balanced')
# Accuracy: 0.9077, Precisión por clase: [0.8911141  0.94076767], Recall por clase: [0.9643351  0.82332082], F1 por clase: [0.92595923 0.87696789]
#
# Hiperparámetros: (50, None, 5, 2, None)
# Accuracy: 0.9117, Precisión por clase: [0.89830889 0.93585637], Recall por clase: [0.96091045 0.83886108], F1 por clase: [0.92847703 0.88445867]
#
# Hiperparámetros: (50, None, 5, 2, 'balanced')
# Accuracy: 0.9036, Precisión por clase: [0.89492182 0.91908411], Recall por clase: [0.95068275 0.83395912], F1 por clase: [0.92184792 0.87413773]
#
# Hiperparámetros: (50, 10, 2, 1, None)
# Accuracy: 0.9179, Precisión por clase: [0.90155554 0.94739756], Recall por clase: [0.9679653  0.84418023], F1 por clase: [0.9334931 0.8925678]
#
# Hiperparámetros: (50, 10, 2, 1, 'balanced')
# Accuracy: 0.9205, Precisión por clase: [0.90730016 0.94348995], Recall por clase: [0.9651831  0.85481852], F1 por clase: [0.93528728 0.89682008]
#
# Hiperparámetros: (50, 10, 2, 2, None)
# Accuracy: 0.9118, Precisión por clase: [0.8985496  0.93575078], Recall por clase: [0.96111598 0.83886108], F1 por clase: [0.92866716 0.88432193]
#
# Hiperparámetros: (50, 10, 2, 2, 'balanced')
# Accuracy: 0.9011, Precisión por clase: [0.8971407  0.90955144], Recall por clase: [0.94303172 0.83886108], F1 por clase: [0.9192571  0.87210228]
#
# Hiperparámetros: (50, 10, 5, 1, None)
# Accuracy: 0.9202, Precisión por clase: [0.90242604 0.95288055], Recall por clase: [0.97168805 0.84459741], F1 por clase: [0.9356152  0.89502292]
#
# Hiperparámetros: (50, 10, 5, 1, 'balanced')
# Accuracy: 0.9075, Precisión por clase: [0.89302533 0.93568728], Recall por clase: [0.96086417 0.82905715], F1 por clase: [0.92539314 0.87822793]
#
# Hiperparámetros: (50, 10, 5, 2, None)
# Accuracy: 0.9156, Precisión por clase: [0.89855863 0.94789905], Recall por clase: [0.96746167 0.83886108], F1 por clase: [0.93160147 0.88960568]
#
# Hiperparámetros: (50, 10, 5, 2, 'balanced')
# Accuracy: 0.9077, Precisión por clase: [0.90004955 0.92294016], Recall por clase: [0.9511401  0.84418023], F1 por clase: [0.92458925 0.88104689]
#
# Hiperparámetros: (50, 20, 2, 1, None)
# Accuracy: 0.9158, Precisión por clase: [0.89890652 0.94712071], Recall por clase: [0.96791902 0.83886108], F1 por clase: [0.93200275 0.8892896 ]
#
# Hiperparámetros: (50, 20, 2, 1, 'balanced')
# Accuracy: 0.9059, Precisión por clase: [0.89562787 0.92479613], Recall por clase: [0.95410741 0.83479349], F1 por clase: [0.92374055 0.87689354]
#
# Hiperparámetros: (50, 20, 2, 2, None)
# Accuracy: 0.9076, Precisión por clase: [0.89289362 0.93532199], Recall por clase: [0.96091045 0.82947434], F1 por clase: [0.92541207 0.87849217]
#
# Hiperparámetros: (50, 20, 2, 2, 'balanced')
# Accuracy: 0.9115, Precisión por clase: [0.89525052 0.94100381], Recall por clase: [0.9643351  0.83354193], F1 por clase: [0.92847534 0.88390446]
#
# Hiperparámetros: (50, 20, 5, 1, None)
# Accuracy: 0.9160, Precisión por clase: [0.89890889 0.94684385], Recall por clase: [0.96821711 0.83886108], F1 por clase: [0.93220802 0.88938428]
#
# Hiperparámetros: (50, 20, 5, 1, 'balanced')
# Accuracy: 0.9054, Precisión por clase: [0.88964176 0.93592804], Recall por clase: [0.96100301 0.82290363], F1 por clase: [0.92377842 0.87513841]
#
# Hiperparámetros: (50, 20, 5, 2, None)
# Accuracy: 0.9181, Precisión por clase: [0.89992477 0.95297619], Recall por clase: [0.97138995 0.83927826], F1 por clase: [0.93406002 0.89180088]
#
# Hiperparámetros: (50, 20, 5, 2, 'balanced')
# Accuracy: 0.9030, Precisión por clase: [0.89475528 0.91994424], Recall por clase: [0.94983476 0.83354193], F1 por clase: [0.92113712 0.87370245]
#
# Hiperparámetros: (100, None, 2, 1, None)
# Accuracy: 0.9140, Precisión por clase: [0.90134699 0.93657505], Recall por clase: [0.96116226 0.84459741], F1 por clase: [0.93017    0.88786533]
#
# Hiperparámetros: (100, None, 2, 1, 'balanced')
# Accuracy: 0.9078, Precisión por clase: [0.88813681 0.94671973], Recall por clase: [0.96830967 0.81800167], F1 por clase: [0.92621065 0.87674528]
#
# Hiperparámetros: (100, None, 2, 2, None)
# Accuracy: 0.9098, Precisión por clase: [0.89805752 0.93089323], Recall por clase: [0.9577376  0.83927826], F1 por clase: [0.92681429 0.88237082]
#
# Hiperparámetros: (100, None, 2, 2, 'balanced')
# Accuracy: 0.9079, Precisión por clase: [0.89557904 0.9297588 ], Recall por clase: [0.95778388 0.83395912], F1 por clase: [0.92555887 0.8790082 ]
#
# Hiperparámetros: (100, None, 5, 1, None)
# Accuracy: 0.9117, Precisión por clase: [0.89312743 0.9463308 ], Recall por clase: [0.96801158 0.82822278], F1 por clase: [0.92898828 0.88304781]
#
# Hiperparámetros: (100, None, 5, 1, 'balanced')
# Accuracy: 0.9160, Precisión por clase: [0.90155565 0.94191743], Recall por clase: [0.9646332  0.84418023], F1 por clase: [0.93197864 0.89021126]
#
# Hiperparámetros: (100, None, 5, 2, None)
# Accuracy: 0.9139, Precisión por clase: [0.90375    0.93178882], Recall por clase: [0.9577376  0.84949937], F1 por clase: [0.92984494 0.88844394]
#
# Hiperparámetros: (100, None, 5, 2, 'balanced')
# Accuracy: 0.9140, Precisión por clase: [0.89601081 0.94669192], Recall por clase: [0.96826339 0.83395912], F1 por clase: [0.93066596 0.88655492]
#
# Hiperparámetros: (100, 10, 2, 1, None)
# Accuracy: 0.9200, Precisión por clase: [0.90446354 0.94766183], Recall por clase: [0.96801158 0.84949937], F1 por clase: [0.93511014 0.89577173]
#
# Hiperparámetros: (100, 10, 2, 1, 'balanced')
# Accuracy: 0.9057, Precisión por clase: [0.88962987 0.93474127], Recall por clase: [0.96146035 0.82332082], F1 por clase: [0.92411459 0.87538543]
#
# Hiperparámetros: (100, 10, 2, 2, None)
# Accuracy: 0.9134, Precisión por clase: [0.89839491 0.94170945], Recall por clase: [0.96399073 0.83886108], F1 por clase: [0.92986694 0.88678792]
#
# Hiperparámetros: (100, 10, 2, 2, 'balanced')
# Accuracy: 0.9120, Precisión por clase: [0.89869602 0.93668831], Recall por clase: [0.96136779 0.83927826], F1 por clase: [0.92876892 0.88470965]
#
# Hiperparámetros: (100, 10, 5, 1, None)
# Accuracy: 0.9160, Precisión por clase: [0.90144226 0.94184788], Recall por clase: [0.96483873 0.84418023], F1 por clase: [0.9320149  0.89021618]
#
# Hiperparámetros: (100, 10, 5, 1, 'balanced')
# Accuracy: 0.9201, Precisión por clase: [0.90211401 0.95279623], Recall por clase: [0.97164177 0.84418023], F1 por clase: [0.93551928 0.89500226]
#
# Hiperparámetros: (100, 10, 5, 2, None)
# Accuracy: 0.9179, Precisión por clase: [0.90435401 0.94224429], Recall por clase: [0.9643351  0.84949937], F1 por clase: [0.93331321 0.89326868]
#
# Hiperparámetros: (100, 10, 5, 2, 'balanced')
# Accuracy: 0.9181, Precisión por clase: [0.90498775 0.94282344], Recall por clase: [0.9643351  0.84991656], F1 por clase: [0.93348776 0.89332976]
#
# Hiperparámetros: (100, 20, 2, 1, None)
# Accuracy: 0.9182, Precisión por clase: [0.90470626 0.9426172 ], Recall por clase: [0.96483873 0.84991656], F1 por clase: [0.93363418 0.89340807]
#
# Hiperparámetros: (100, 20, 2, 1, 'balanced')
# Accuracy: 0.9204, Precisión por clase: [0.90550526 0.9478824 ], Recall por clase: [0.96801158 0.84991656], F1 por clase: [0.93554339 0.89571466]
#
# Hiperparámetros: (100, 20, 2, 2, None)
# Accuracy: 0.9137, Precisión por clase: [0.89575362 0.94680233], Recall por clase: [0.96821711 0.83354193], F1 por clase: [0.93045788 0.8862395 ]
#
# Hiperparámetros: (100, 20, 2, 2, 'balanced')
# Accuracy: 0.9139, Precisión por clase: [0.89669917 0.94614978], Recall por clase: [0.9679653  0.83354193], F1 por clase: [0.93080002 0.88569803]
#
# Hiperparámetros: (100, 20, 5, 1, None)
# Accuracy: 0.9160, Precisión por clase: [0.89659553 0.95298765], Recall por clase: [0.97143623 0.83354193], F1 por clase: [0.93237327 0.88869969]
#
# Hiperparámetros: (100, 20, 5, 1, 'balanced')
# Accuracy: 0.9139, Precisión por clase: [0.8962532  0.94760666], Recall por clase: [0.96775976 0.83395912], F1 por clase: [0.93046558 0.88657334]
#
# Hiperparámetros: (100, 20, 5, 2, None)
# Accuracy: 0.9095, Precisión por clase: [0.8956339  0.93631078], Recall por clase: [0.96081789 0.83395912], F1 por clase: [0.92682538 0.8813731 ]
#
# Hiperparámetros: (100, 20, 5, 2, 'balanced')
# Accuracy: 0.9120, Precisión por clase: [0.89835584 0.93616606], Recall por clase: [0.96146035 0.83927826], F1 por clase: [0.9287891  0.88495302]
#
# Hiperparámetros: (200, None, 2, 1, None)
# Accuracy: 0.9179, Precisión por clase: [0.90707975 0.93760864], Recall por clase: [0.96086417 0.85481852], F1 por clase: [0.93301258 0.89378834]
#
# Hiperparámetros: (200, None, 2, 1, 'balanced')
# Accuracy: 0.9225, Precisión por clase: [0.90293396 0.95885369], Recall por clase: [0.9751127  0.84459741], F1 por clase: [0.93751597 0.89771137]
#
# Hiperparámetros: (200, None, 2, 2, None)
# Accuracy: 0.9160, Precisión por clase: [0.90144231 0.94170945], Recall por clase: [0.96458692 0.84418023], F1 por clase: [0.93190329 0.89015376]
#
# Hiperparámetros: (200, None, 2, 2, 'balanced')
# Accuracy: 0.9160, Precisión por clase: [0.90164603 0.94186047], Recall por clase: [0.96458692 0.84459741], F1 por clase: [0.93195971 0.89030733]
#
# Hiperparámetros: (200, None, 5, 1, None)
# Accuracy: 0.9241, Precisión por clase: [0.90259531 0.96427221], Recall por clase: [0.9784448  0.84418023], F1 por clase: [0.93887678 0.89989424]
#
# Hiperparámetros: (200, None, 5, 1, 'balanced')
# Accuracy: 0.9163, Precisión por clase: [0.89708413 0.95271424], Recall por clase: [0.97198614 0.83354193], F1 por clase: [0.9328773  0.88855666]
#
# Hiperparámetros: (200, None, 5, 2, None)
# Accuracy: 0.9223, Precisión por clase: [0.90534171 0.95306051], Recall por clase: [0.97164177 0.84949937], F1 por clase: [0.93721506 0.89799371]
#
# Hiperparámetros: (200, None, 5, 2, 'balanced')
# Accuracy: 0.9120, Precisión por clase: [0.89839619 0.93596505], Recall por clase: [0.96146035 0.83886108], F1 por clase: [0.92880074 0.88459329]
#
# Hiperparámetros: (200, 10, 2, 1, None)
# Accuracy: 0.9221, Precisión por clase: [0.90768524 0.94807082], Recall por clase: [0.9679653  0.85481852], F1 por clase: [0.93673083 0.89867898]
#
# Hiperparámetros: (200, 10, 2, 1, 'balanced')
# Accuracy: 0.9139, Precisión por clase: [0.89855433 0.94144518], Recall por clase: [0.96458692 0.83927826], F1 por clase: [0.9303133  0.88718623]
#
# Hiperparámetros: (200, 10, 2, 2, None)
# Accuracy: 0.9118, Precisión por clase: [0.8987187  0.93579545], Recall por clase: [0.96091045 0.83886108], F1 por clase: [0.92864213 0.88424576]
#
# Hiperparámetros: (200, 10, 2, 2, 'balanced')
# Accuracy: 0.9160, Precisión por clase: [0.90694239 0.93181818], Recall por clase: [0.95748579 0.85481852], F1 por clase: [0.93142759 0.8913823 ]
#
# Hiperparámetros: (200, 10, 5, 1, None)
# Accuracy: 0.9180, Precisión por clase: [0.90435606 0.94212474], Recall por clase: [0.96458692 0.84949937], F1 por clase: [0.93344854 0.89327485]
#
# Hiperparámetros: (200, 10, 5, 1, 'balanced')
# Accuracy: 0.9245, Precisión por clase: [0.91090714 0.94832251], Recall por clase: [0.96826339 0.86013767], F1 por clase: [0.93861002 0.90181569]
#
# Hiperparámetros: (200, 10, 5, 2, None)
# Accuracy: 0.9178, Precisión por clase: [0.90421302 0.94225687], Recall por clase: [0.96428883 0.84949937], F1 por clase: [0.9331594  0.89312343]
#
# Hiperparámetros: (200, 10, 5, 2, 'balanced')
# Accuracy: 0.9225, Precisión por clase: [0.91055992 0.94301948], Recall por clase: [0.96488501 0.86013767], F1 por clase: [0.93687143 0.89951306]
#
# Hiperparámetros: (200, 20, 2, 1, None)
# Accuracy: 0.9201, Precisión por clase: [0.904902   0.94790002], Recall por clase: [0.96821711 0.84949937], F1 por clase: [0.93532242 0.89554461]
#
# Hiperparámetros: (200, 20, 2, 1, 'balanced')
# Accuracy: 0.9204, Precisión por clase: [0.91020872 0.93806153], Recall por clase: [0.96125482 0.86013767], F1 por clase: [0.93497464 0.89725259]
#
# Hiperparámetros: (200, 20, 2, 2, None)
# Accuracy: 0.9180, Precisión por clase: [0.90163459 0.94737147], Recall por clase: [0.96826339 0.84418023], F1 por clase: [0.93370005 0.89264354]
#
# Hiperparámetros: (200, 20, 2, 2, 'balanced')
# Accuracy: 0.9140, Precisión por clase: [0.90137293 0.93706165], Recall por clase: [0.96141407 0.84459741], F1 por clase: [0.9302558  0.88797329]
#
# Hiperparámetros: (200, 20, 5, 1, None)
# Accuracy: 0.9179, Precisión por clase: [0.89900037 0.95261628], Recall por clase: [0.97164177 0.83886108], F1 por clase: [0.93379121 0.89179506]
#
# Hiperparámetros: (200, 20, 5, 1, 'balanced')
# Accuracy: 0.9183, Precisión por clase: [0.90229293 0.94724655], Recall por clase: [0.96826339 0.84459741], F1 por clase: [0.93400994 0.89267456]
#
# Hiperparámetros: (200, 20, 5, 2, None)
# Accuracy: 0.9161, Precisión por clase: [0.89906523 0.94698228], Recall por clase: [0.96826339 0.83927826], F1 por clase: [0.93231415 0.88968311]
#
# Hiperparámetros: (200, 20, 5, 2, 'balanced')
# Accuracy: 0.9224, Precisión por clase: [0.90791671 0.9479261 ], Recall por clase: [0.96826339 0.85481852], F1 por clase: [0.93704402 0.89876319]
#
# Mejores hiperparámetros para window_5s: (200, 10, 5, 1, 'balanced'), Mejor F1 promedio: 0.9202
#
# Evaluando dataset: window_3s
#
# Hiperparámetros: (50, None, 2, 1, None)
# Accuracy: 0.8840, Precisión por clase: [0.89268185 0.86750033], Recall por clase: [0.93418046 0.7906868 ], F1 por clase: [0.91271641 0.82626035]
#
# Hiperparámetros: (50, None, 2, 1, 'balanced')
# Accuracy: 0.8876, Precisión por clase: [0.89001753 0.88430943], Recall por clase: [0.94365956 0.7843959 ], F1 por clase: [0.91588331 0.8305908 ]
#
# Hiperparámetros: (50, None, 2, 2, None)
# Accuracy: 0.8926, Precisión por clase: [0.89512443 0.88883025], Recall por clase: [0.94556848 0.79437687], F1 por clase: [0.9195044 0.8381569]
#
# Hiperparámetros: (50, None, 2, 2, 'balanced')
# Accuracy: 0.8773, Precisión por clase: [0.89093772 0.85012778], Recall por clase: [0.92391012 0.7911211 ], F1 por clase: [0.90705752 0.81929122]
#
# Hiperparámetros: (50, None, 5, 1, None)
# Accuracy: 0.8937, Precisión por clase: [0.89955362 0.88116676], Recall por clase: [0.94154061 0.8052559 ], F1 por clase: [0.92004527 0.84139382]
#
# Hiperparámetros: (50, None, 5, 1, 'balanced')
# Accuracy: 0.8838, Precisión por clase: [0.89679023 0.85758376], Recall por clase: [0.92808713 0.80173757], F1 por clase: [0.91208287 0.82837295]
#
# Hiperparámetros: (50, None, 5, 2, None)
# Accuracy: 0.8975, Precisión por clase: [0.90302784 0.88575978], Recall por clase: [0.94341086 0.81251601], F1 por clase: [0.92274521 0.84740996]
#
# Hiperparámetros: (50, None, 5, 2, 'balanced')
# Accuracy: 0.8964, Precisión por clase: [0.89703968 0.8948433 ], Recall por clase: [0.9492777  0.79831286], F1 por clase: [0.92240575 0.84375056]
#
# Hiperparámetros: (50, 10, 2, 1, None)
# Accuracy: 0.8813, Precisión por clase: [0.89194755 0.86020389], Recall por clase: [0.93024345 0.7911197 ], F1 por clase: [0.91051931 0.82358821]
#
# Hiperparámetros: (50, 10, 2, 1, 'balanced')
# Accuracy: 0.8864, Precisión por clase: [0.89109831 0.87773062], Recall por clase: [0.94029665 0.78723401], F1 por clase: [0.91481214 0.82919271]
#
# Hiperparámetros: (50, 10, 2, 2, None)
# Accuracy: 0.8951, Precisión por clase: [0.90153623 0.8831357 ], Recall por clase: [0.9414356  0.80882733], F1 por clase: [0.92091145 0.84366342]
#
# Hiperparámetros: (50, 10, 2, 2, 'balanced')
# Accuracy: 0.8874, Precisión por clase: [0.90000229 0.8617186 ], Recall por clase: [0.92967065 0.80926023], F1 por clase: [0.91457231 0.83457846]
#
# Hiperparámetros: (50, 10, 5, 1, None)
# Accuracy: 0.8787, Precisión por clase: [0.89460153 0.84776111], Recall por clase: [0.92236268 0.79763124], F1 por clase: [0.90804716 0.82111143]
#
# Hiperparámetros: (50, 10, 5, 1, 'balanced')
# Accuracy: 0.8890, Precisión por clase: [0.90184775 0.86327938], Recall por clase: [0.93010106 0.81309981], F1 por clase: [0.91572756 0.83732056]
#
# Hiperparámetros: (50, 10, 5, 2, None)
# Accuracy: 0.8937, Precisión por clase: [0.8994179  0.88133741], Recall por clase: [0.94139693 0.80552266], F1 por clase: [0.91992784 0.84172427]
#
# Hiperparámetros: (50, 10, 5, 2, 'balanced')
# Accuracy: 0.8975, Precisión por clase: [0.90636709 0.87900783], Recall por clase: [0.93971515 0.81912676], F1 por clase: [0.92269023 0.8477867 ]
#
# Hiperparámetros: (50, 20, 2, 1, None)
# Accuracy: 0.8852, Precisión por clase: [0.89138974 0.87182609], Recall por clase: [0.93769446 0.78731518], F1 por clase: [0.91390002 0.82712274]
#
# Hiperparámetros: (50, 20, 2, 1, 'balanced')
# Accuracy: 0.8852, Precisión por clase: [0.89544781 0.86443723], Recall por clase: [0.93197066 0.79826395], F1 por clase: [0.91326271 0.82967118]
#
# Hiperparámetros: (50, 20, 2, 2, None)
# Accuracy: 0.8890, Precisión por clase: [0.89461603 0.87693065], Recall por clase: [0.93990426 0.79447607], F1 por clase: [0.91663633 0.83335746]
#
# Hiperparámetros: (50, 20, 2, 2, 'balanced')
# Accuracy: 0.8864, Precisión por clase: [0.89851656 0.86148147], Recall por clase: [0.92995673 0.80557296], F1 por clase: [0.91393537 0.83246831]
#
# Hiperparámetros: (50, 20, 5, 1, None)
# Accuracy: 0.8825, Precisión por clase: [0.89359859 0.86035021], Recall por clase: [0.9300028  0.79442577], F1 por clase: [0.9113229  0.82555729]
#
# Hiperparámetros: (50, 20, 5, 1, 'balanced')
# Accuracy: 0.8889, Precisión por clase: [0.89012292 0.88653265], Recall por clase: [0.94571892 0.78386099], F1 por clase: [0.91701473 0.83173144]
#
# Hiperparámetros: (50, 20, 5, 2, None)
# Accuracy: 0.8853, Precisión por clase: [0.89273532 0.86954215], Recall por clase: [0.93577138 0.79163656], F1 por clase: [0.91373022 0.8286719 ]
#
# Hiperparámetros: (50, 20, 5, 2, 'balanced')
# Accuracy: 0.8826, Precisión por clase: [0.90142245 0.84747369], Recall por clase: [0.92029786 0.8120356 ], F1 por clase: [0.91051998 0.82837156]
#
# Hiperparámetros: (100, None, 2, 1, None)
# Accuracy: 0.8928, Precisión por clase: [0.90421388 0.87014156], Recall por clase: [0.93418851 0.81587098], F1 por clase: [0.91884175 0.84163696]
#
# Hiperparámetros: (100, None, 2, 1, 'balanced')
# Accuracy: 0.8853, Precisión por clase: [0.88680604 0.88387737], Recall por clase: [0.94403779 0.77676984], F1 por clase: [0.91433178 0.82600348]
#
# Hiperparámetros: (100, None, 2, 2, None)
# Accuracy: 0.8903, Precisión por clase: [0.8977046  0.87505439], Recall por clase: [0.93788357 0.80205043], F1 por clase: [0.91728931 0.83666769]
#
# Hiperparámetros: (100, None, 2, 2, 'balanced')
# Accuracy: 0.8825, Precisión por clase: [0.89947462 0.84945887], Recall por clase: [0.92188878 0.80909548], F1 por clase: [0.91046775 0.82850199]
#
# Hiperparámetros: (100, None, 5, 1, None)
# Accuracy: 0.8891, Precisión por clase: [0.90398666 0.85984896], Recall por clase: [0.92827559 0.81602049], F1 por clase: [0.91587515 0.83695777]
#
# Hiperparámetros: (100, None, 5, 1, 'balanced')
# Accuracy: 0.8914, Precisión por clase: [0.89496036 0.88487364], Recall por clase: [0.94350977 0.79447607], F1 por clase: [0.91847394 0.83666533]
#
# Hiperparámetros: (100, None, 5, 2, None)
# Accuracy: 0.8927, Precisión por clase: [0.89380307 0.8911445 ], Recall por clase: [0.94749896 0.7907371 ], F1 por clase: [0.91975901 0.83738205]
#
# Hiperparámetros: (100, None, 5, 2, 'balanced')
# Accuracy: 0.8863, Precisión por clase: [0.90167397 0.85572205], Recall por clase: [0.92616405 0.81234986], F1 por clase: [0.91369785 0.83323215]
#
# Hiperparámetros: (100, 10, 2, 1, None)
# Accuracy: 0.8838, Precisión por clase: [0.8953107  0.86047379], Recall por clase: [0.93010041 0.7979469 ], F1 por clase: [0.91225807 0.82755742]
#
# Hiperparámetros: (100, 10, 2, 1, 'balanced')
# Accuracy: 0.8936, Precisión por clase: [0.89504413 0.89032638], Recall por clase: [0.94711333 0.79442577], F1 por clase: [0.92032789 0.8395549 ]
#
# Hiperparámetros: (100, 10, 2, 2, None)
# Accuracy: 0.8853, Precisión por clase: [0.88960087 0.87646336], Recall por clase: [0.94000317 0.7839099 ], F1 por clase: [0.91402383 0.82720397]
#
# Hiperparámetros: (100, 10, 2, 2, 'balanced')
# Accuracy: 0.8838, Precisión por clase: [0.90130931 0.85020559], Recall por clase: [0.92203247 0.81234986], F1 por clase: [0.91142752 0.83034105]
#
# Hiperparámetros: (100, 10, 5, 1, None)
# Accuracy: 0.8902, Precisión por clase: [0.90079218 0.86840387], Recall por clase: [0.93394657 0.80887763], F1 por clase: [0.91702063 0.83735756]
#
# Hiperparámetros: (100, 10, 5, 1, 'balanced')
# Accuracy: 0.8928, Precisión por clase: [0.89986589 0.87923169], Recall por clase: [0.9394745  0.80625597], F1 por clase: [0.91914605 0.84075867]
#
# Hiperparámetros: (100, 10, 5, 2, None)
# Accuracy: 0.8902, Precisión por clase: [0.89768324 0.87483424], Recall por clase: [0.93793641 0.80178508], F1 por clase: [0.91730526 0.83642973]
#
# Hiperparámetros: (100, 10, 5, 2, 'balanced')
# Accuracy: 0.8827, Precisión por clase: [0.89966516 0.85014457], Recall por clase: [0.92212267 0.80914439], F1 por clase: [0.91064791 0.82868571]
#
# Hiperparámetros: (100, 20, 2, 1, None)
# Accuracy: 0.8824, Precisión por clase: [0.88914018 0.86776077], Recall por clase: [0.935869   0.78359424], F1 por clase: [0.91185121 0.82330329]
#
# Hiperparámetros: (100, 20, 2, 1, 'balanced')
# Accuracy: 0.8864, Precisión por clase: [0.89434955 0.8701201 ], Recall por clase: [0.93601333 0.79420932], F1 por clase: [0.91459059 0.82987431]
#
# Hiperparámetros: (100, 20, 2, 2, None)
# Accuracy: 0.8889, Precisión por clase: [0.89916537 0.86799178], Recall por clase: [0.93384831 0.80535511], F1 por clase: [0.91609369 0.83514874]
#
# Hiperparámetros: (100, 20, 2, 2, 'balanced')
# Accuracy: 0.8901, Precisión por clase: [0.90080664 0.8683896 ], Recall por clase: [0.93404483 0.80856198], F1 por clase: [0.91703641 0.83701616]
#
# Hiperparámetros: (100, 20, 5, 1, None)
# Accuracy: 0.8930, Precisión por clase: [0.90605638 0.86794031], Recall por clase: [0.9322126  0.81980837], F1 por clase: [0.91882119 0.84262915]
#
# Hiperparámetros: (100, 20, 5, 1, 'balanced')
# Accuracy: 0.8876, Precisión por clase: [0.89411809 0.87348482], Recall por clase: [0.9378375  0.79490897], F1 por clase: [0.91542511 0.83224238]
#
# Hiperparámetros: (100, 20, 5, 2, None)
# Accuracy: 0.8890, Precisión por clase: [0.90079436 0.86557998], Recall por clase: [0.93202414 0.80892654], F1 por clase: [0.91604886 0.83586582]
#
# Hiperparámetros: (100, 20, 5, 2, 'balanced')
# Accuracy: 0.8977, Precisión por clase: [0.90469276 0.88280229], Recall por clase: [0.94168365 0.81613774], F1 por clase: [0.92279952 0.84807863]
#
# Hiperparámetros: (200, None, 2, 1, None)
# Accuracy: 0.8890, Precisión por clase: [0.89797664 0.87208638], Recall por clase: [0.93600528 0.80130188], F1 por clase: [0.91636209 0.83414597]
#
# Hiperparámetros: (200, None, 2, 1, 'balanced')
# Accuracy: 0.8911, Precisión por clase: [0.89330723 0.88608298], Recall por clase: [0.94543155 0.79058899], F1 por clase: [0.91858438 0.83539452]
#
# Hiperparámetros: (200, None, 2, 2, None)
# Accuracy: 0.8939, Precisión por clase: [0.89989559 0.88140466], Recall por clase: [0.94158604 0.80508976], F1 por clase: [0.92019864 0.84116492]
#
# Hiperparámetros: (200, None, 2, 2, 'balanced')
# Accuracy: 0.8901, Precisión por clase: [0.89900636 0.87151534], Recall por clase: [0.9359679 0.805207 ], F1 por clase: [0.91704815 0.83678158]
#
# Hiperparámetros: (200, None, 5, 1, None)
# Accuracy: 0.8965, Precisión por clase: [0.90645277 0.87772108], Recall por clase: [0.93768705 0.81975807], F1 por clase: [0.92166121 0.84713735]
#
# Hiperparámetros: (200, None, 5, 1, 'balanced')
# Accuracy: 0.8901, Precisión por clase: [0.8963476 0.8775014], Recall por clase: [0.94000252 0.79768154], F1 por clase: [0.91752218 0.83508081]
#
# Hiperparámetros: (200, None, 5, 2, None)
# Accuracy: 0.8902, Precisión por clase: [0.90069692 0.869017  ], Recall por clase: [0.93409025 0.80877843], F1 por clase: [0.91699231 0.83739305]
#
# Hiperparámetros: (200, None, 5, 2, 'balanced')
# Accuracy: 0.8875, Precisión por clase: [0.90181198 0.85994612], Recall por clase: [0.92807972 0.81225065], F1 por clase: [0.91460823 0.83480215]
#
# Hiperparámetros: (200, 10, 2, 1, None)
# Accuracy: 0.8978, Precisión por clase: [0.90619167 0.88063187], Recall por clase: [0.93995709 0.81992561], F1 por clase: [0.92272718 0.84905161]
#
# Hiperparámetros: (200, 10, 2, 1, 'balanced')
# Accuracy: 0.8866, Precisión por clase: [0.8943335  0.87032964], Recall por clase: [0.9359679  0.79484203], F1 por clase: [0.91462619 0.83064536]
#
# Hiperparámetros: (200, 10, 2, 2, None)
# Accuracy: 0.8888, Precisión por clase: [0.89926393 0.86816734], Recall por clase: [0.93409025 0.8047238 ], F1 por clase: [0.91617013 0.83445074]
#
# Hiperparámetros: (200, 10, 2, 2, 'balanced')
# Accuracy: 0.8863, Precisión por clase: [0.89714586 0.86488538], Recall por clase: [0.93173806 0.80151833], F1 por clase: [0.91399277 0.83144101]
#
# Hiperparámetros: (200, 10, 5, 1, None)
# Accuracy: 0.8902, Precisión por clase: [0.90095902 0.86845798], Recall por clase: [0.93384831 0.80892654], F1 por clase: [0.91702355 0.83727292]
#
# Hiperparámetros: (200, 10, 5, 1, 'balanced')
# Accuracy: 0.8926, Precisión por clase: [0.90080221 0.87613329], Recall por clase: [0.9375975  0.80931053], F1 por clase: [0.91879548 0.8412199 ]
#
# Hiperparámetros: (200, 10, 5, 2, None)
# Accuracy: 0.8889, Precisión por clase: [0.8947678  0.87655777], Recall por clase: [0.93976122 0.79425823], F1 por clase: [0.91662619 0.83293718]
#
# Hiperparámetros: (200, 10, 5, 2, 'balanced')
# Accuracy: 0.8913, Precisión por clase: [0.89785858 0.87777984], Recall por clase: [0.93990426 0.80141912], F1 por clase: [0.91829593 0.83740489]
#
# Hiperparámetros: (200, 20, 2, 1, None)
# Accuracy: 0.8915, Precisión por clase: [0.90266408 0.86969991], Recall por clase: [0.93389373 0.81271442], F1 por clase: [0.91790041 0.83978186]
#
# Hiperparámetros: (200, 20, 2, 1, 'balanced')
# Accuracy: 0.8888, Precisión por clase: [0.89153482 0.88264903], Recall por clase: [0.9435539  0.78738352], F1 por clase: [0.91677439 0.83212685]
#
# Hiperparámetros: (200, 20, 2, 2, None)
# Accuracy: 0.8952, Precisión por clase: [0.89710464 0.89130427], Recall por clase: [0.94754374 0.7980461 ], F1 por clase: [0.92157335 0.84176684]
#
# Hiperparámetros: (200, 20, 2, 2, 'balanced')
# Accuracy: 0.8902, Precisión por clase: [0.89624964 0.87748404], Recall por clase: [0.93976122 0.79831286], F1 por clase: [0.91745407 0.83584296]
#
# Hiperparámetros: (200, 20, 5, 1, None)
# Accuracy: 0.8941, Precisión por clase: [0.90302268 0.875965  ], Recall por clase: [0.93783815 0.81276472], F1 por clase: [0.92005671 0.84296577]
#
# Hiperparámetros: (200, 20, 5, 1, 'balanced')
# Accuracy: 0.8926, Precisión por clase: [0.89799935 0.88159526], Recall por clase: [0.94188017 0.80146942], F1 por clase: [0.9193204  0.83922538]
#
# Hiperparámetros: (200, 20, 5, 2, None)
# Accuracy: 0.8875, Precisión por clase: [0.89418002 0.87331763], Recall por clase: [0.93789098 0.79437547], F1 por clase: [0.91544651 0.83169696]
#
# Hiperparámetros: (200, 20, 5, 2, 'balanced')
# Accuracy: 0.8902, Precisión por clase: [0.89908144 0.87220261], Recall por clase: [0.93611159 0.805207  ], F1 por clase: [0.9171115  0.83691053]
#
# Mejores hiperparámetros para window_3s: (200, 10, 2, 1, None), Mejor F1 promedio: 0.8859
#
# Evaluando dataset: window_1s
#
# Hiperparámetros: (50, None, 2, 1, None)
# Accuracy: 0.8919, Precisión por clase: [0.91286053 0.83855488], Recall por clase: [0.93652656 0.78457467], F1 por clase: [0.92439775 0.80987591]
#
# Hiperparámetros: (50, None, 2, 1, 'balanced')
# Accuracy: 0.8923, Precisión por clase: [0.90845562 0.84844195], Recall por clase: [0.94255771 0.77138427], F1 por clase: [0.9251437  0.80776495]
#
# Hiperparámetros: (50, None, 2, 2, None)
# Accuracy: 0.8900, Precisión por clase: [0.91056179 0.83710917], Recall por clase: [0.93618391 0.77948033], F1 por clase: [0.9231246  0.80686547]
#
# Hiperparámetros: (50, None, 2, 2, 'balanced')
# Accuracy: 0.8906, Precisión por clase: [0.91545547 0.82883795], Recall por clase: [0.93111235 0.79320158], F1 por clase: [0.92313328 0.8101196 ]
#
# Hiperparámetros: (50, None, 5, 1, None)
# Accuracy: 0.8924, Precisión por clase: [0.91418343 0.83847543], Recall por clase: [0.93577275 0.78791382], F1 por clase: [0.92464033 0.81120902]
#
# Hiperparámetros: (50, None, 5, 1, 'balanced')
# Accuracy: 0.8868, Precisión por clase: [0.90872099 0.82981561], Recall por clase: [0.93357156 0.77451248], F1 por clase: [0.92092792 0.80088923]
#
# Hiperparámetros: (50, None, 5, 2, None)
# Accuracy: 0.8970, Precisión por clase: [0.91811882 0.84321819], Recall por clase: [0.93788128 0.79900869], F1 por clase: [0.92784243 0.82022136]
#
# Hiperparámetros: (50, None, 5, 2, 'balanced')
# Accuracy: 0.8868, Precisión por clase: [0.91679302 0.81420688], Recall por clase: [0.92344593 0.79878944], F1 por clase: [0.92004069 0.80607514]
#
# Hiperparámetros: (50, 10, 2, 1, None)
# Accuracy: 0.8921, Precisión por clase: [0.91236491 0.83925034], Recall por clase: [0.93731033 0.78336695], F1 por clase: [0.9245899  0.80989127]
#
# Hiperparámetros: (50, 10, 2, 1, 'balanced')
# Accuracy: 0.8765, Precisión por clase: [0.90884415 0.80120732], Recall por clase: [0.91753741 0.77729307], F1 por clase: [0.91279746 0.78721454]
#
# Hiperparámetros: (50, 10, 2, 2, None)
# Accuracy: 0.8958, Precisión por clase: [0.91312575 0.84980752], Recall por clase: [0.94207988 0.7847831 ], F1 por clase: [0.92734869 0.81582188]
#
# Hiperparámetros: (50, 10, 2, 2, 'balanced')
# Accuracy: 0.8889, Precisión por clase: [0.91261181 0.82906194], Recall por clase: [0.93179316 0.78571491], F1 por clase: [0.92203587 0.80639978]
#
# Hiperparámetros: (50, 10, 5, 1, None)
# Accuracy: 0.8895, Precisión por clase: [0.91180461 0.83314262], Recall por clase: [0.93414614 0.78176908], F1 por clase: [0.9226743  0.80566605]
#
# Hiperparámetros: (50, 10, 5, 1, 'balanced')
# Accuracy: 0.8899, Precisión por clase: [0.9119175  0.83271895], Recall por clase: [0.93428439 0.78308186], F1 por clase: [0.92293227 0.8069248 ]
#
# Hiperparámetros: (50, 10, 5, 2, None)
# Accuracy: 0.9001, Precisión por clase: [0.91439864 0.86245506], Recall por clase: [0.94736009 0.78681447], F1 por clase: [0.9305089  0.82236844]
#
# Hiperparámetros: (50, 10, 5, 2, 'balanced')
# Accuracy: 0.8898, Precisión por clase: [0.91713721 0.82195226], Recall por clase: [0.92768953 0.79862354], F1 por clase: [0.92235078 0.80994079]
#
# Hiperparámetros: (50, 20, 2, 1, None)
# Accuracy: 0.8957, Precisión por clase: [0.91068518 0.85514524], Recall por clase: [0.9449489  0.77748398], F1 por clase: [0.9274617  0.81422084]
#
# Hiperparámetros: (50, 20, 2, 1, 'balanced')
# Accuracy: 0.8776, Precisión por clase: [0.9006363  0.82091636], Recall por clase: [0.92950263 0.75279436], F1 por clase: [0.91453098 0.7837092 ]
#
# Hiperparámetros: (50, 20, 2, 2, None)
# Accuracy: 0.8959, Precisión por clase: [0.91288468 0.85126393], Recall por clase: [0.94259266 0.78384797], F1 por clase: [0.92742265 0.81567731]
#
# Hiperparámetros: (50, 20, 2, 2, 'balanced')
# Accuracy: 0.8860, Precisión por clase: [0.91486514 0.81558936], Recall por clase: [0.92472358 0.79326742], F1 por clase: [0.91968114 0.80381697]
#
# Hiperparámetros: (50, 20, 5, 1, None)
# Accuracy: 0.8980, Precisión por clase: [0.91424136 0.85413955], Recall por clase: [0.94400132 0.78750783], F1 por clase: [0.92887154 0.81940686]
#
# Hiperparámetros: (50, 20, 5, 1, 'balanced')
# Accuracy: 0.8803, Precisión por clase: [0.90621527 0.81851038], Recall por clase: [0.92710732 0.7673609 ], F1 por clase: [0.91611344 0.7898858 ]
#
# Hiperparámetros: (50, 20, 5, 2, None)
# Accuracy: 0.8908, Precisión por clase: [0.91150985 0.83604233], Recall por clase: [0.93621881 0.78173155], F1 por clase: [0.92368273 0.8078816 ]
#
# Hiperparámetros: (50, 20, 5, 2, 'balanced')
# Accuracy: 0.8882, Precisión por clase: [0.91169964 0.82829025], Recall por clase: [0.93184313 0.78321606], F1 por clase: [0.9216099  0.80479824]
#
# Hiperparámetros: (100, None, 2, 1, None)
# Accuracy: 0.8876, Precisión por clase: [0.91130635 0.82801025], Recall por clase: [0.93161407 0.78187745], F1 por clase: [0.9212325  0.80361424]
#
# Hiperparámetros: (100, None, 2, 1, 'balanced')
# Accuracy: 0.8880, Precisión por clase: [0.90612383 0.83984879], Recall por clase: [0.93876576 0.76568884], F1 por clase: [0.922051   0.80039608]
#
# Hiperparámetros: (100, None, 2, 2, None)
# Accuracy: 0.8934, Precisión por clase: [0.91184495 0.84414645], Recall por clase: [0.93980066 0.78194748], F1 por clase: [0.92559558 0.81176034]
#
# Hiperparámetros: (100, None, 2, 2, 'balanced')
# Accuracy: 0.8862, Precisión por clase: [0.91586908 0.81441912], Recall por clase: [0.92386871 0.79560201], F1 por clase: [0.91974308 0.80433995]
#
# Hiperparámetros: (100, None, 5, 1, None)
# Accuracy: 0.8996, Precisión por clase: [0.91422659 0.86059992], Recall por clase: [0.9467363  0.78634095], F1 por clase: [0.93013208 0.82137097]
#
# Hiperparámetros: (100, None, 5, 1, 'balanced')
# Accuracy: 0.8803, Precisión por clase: [0.90656612 0.81401699], Recall por clase: [0.92618986 0.76972468], F1 por clase: [0.91612308 0.7904533 ]
#
# Hiperparámetros: (100, None, 5, 2, None)
# Accuracy: 0.8958, Precisión por clase: [0.91321795 0.85025005], Recall por clase: [0.94204192 0.7850832 ], F1 por clase: [0.92734263 0.81598361]
#
# Hiperparámetros: (100, None, 5, 2, 'balanced')
# Accuracy: 0.8910, Precisión por clase: [0.918742   0.82332205], Recall por clase: [0.92767656 0.80311455], F1 por clase: [0.92313857 0.81282882]
#
# Hiperparámetros: (100, 10, 2, 1, None)
# Accuracy: 0.8951, Precisión por clase: [0.91615913 0.84051198], Recall por clase: [0.93734527 0.79328994], F1 por clase: [0.92657976 0.81589519]
#
# Hiperparámetros: (100, 10, 2, 1, 'balanced')
# Accuracy: 0.8825, Precisión por clase: [0.91211143 0.81090063], Recall por clase: [0.92258001 0.78600583], F1 por clase: [0.91717213 0.79745659]
#
# Hiperparámetros: (100, 10, 2, 2, None)
# Accuracy: 0.8943, Precisión por clase: [0.91218127 0.8463608 ], Recall por clase: [0.94101023 0.78201584], F1 por clase: [0.926335   0.81268871]
#
# Hiperparámetros: (100, 10, 2, 2, 'balanced')
# Accuracy: 0.8903, Precisión por clase: [0.91450136 0.82908272], Recall por clase: [0.93182212 0.79045433], F1 por clase: [0.92301958 0.80894488]
#
# Hiperparámetros: (100, 10, 5, 1, None)
# ...
#
# Hiperparámetros: (200, 20, 2, 1, None)
# Accuracy: 0.8899, Precisión por clase: [0.8874187  0.89563937], Recall por clase: [0.93786653 0.81711332], F1 por clase: [0.91170047 0.85388115]
#
# Hiperparámetros: (200, 20, 2, 1, 'balanced')
# Accuracy: 0.8911, Precisión por clase: [0.88637671 0.90172764], Recall por clase: [0.94179727 0.81415279], F1 por clase: [0.91290863 0.85472603]
#
# Hiperparámetros: (200, 20, 2, 2, None)
# Accuracy: 0.8948, Precisión por clase: [0.89439963 0.89647981], Recall por clase: [0.9376306  0.83001822], F1 por clase: [0.91526007 0.86131943]
#
# Hiperparámetros: (200, 20, 2, 2, 'balanced')
# Accuracy: 0.8836, Precisión por clase: [0.88504742 0.88270603], Recall por clase: [0.92940681 0.8143141 ], F1 por clase: [0.90636229 0.84627105]
#
# Hiperparámetros: (200, 20, 5, 1, None)
# Accuracy: 0.8938, Precisión por clase: [0.89277324 0.89729071], Recall por clase: [0.93795711 0.8268141 ], F1 por clase: [0.91451268 0.85977203]
#
# Hiperparámetros: (200, 20, 5, 1, 'balanced')
# Accuracy: 0.8899, Precisión por clase: [0.88611139 0.89836084], Recall por clase: [0.93985929 0.81415279], F1 por clase: [0.91189522 0.85334528]
#
# Hiperparámetros: (200, 20, 5, 2, None)
# Accuracy: 0.8963, Precisión por clase: [0.89178945 0.90760375], Recall por clase: [0.94438827 0.82344243], F1 por clase: [0.91683691 0.86196315]
#
# Hiperparámetros: (200, 20, 5, 2, 'balanced')
# Accuracy: 0.8898, Precisión por clase: [0.88770923 0.89561137], Recall por clase: [0.93777595 0.81735691], F1 por clase: [0.91166922 0.85362278]
#
# Mejores hiperparámetros para window_5s_overlapped: (200, 10, 2, 2, None), Mejor F1 promedio: 0.8961
#
# Evaluando dataset: window_3s_overlapped
#
# Hiperparámetros: (50, None, 2, 1, None)
# Accuracy: 0.8957, Precisión por clase: [0.90470702 0.87664613], Recall por clase: [0.93993032 0.81197649], F1 por clase: [0.92194642 0.84293262]
#
# Hiperparámetros: (50, None, 2, 1, 'balanced')
# Accuracy: 0.9030, Precisión por clase: [0.90175545 0.90750711], Recall por clase: [0.95602484 0.80263502], F1 por clase: [0.92796894 0.85127322]
#
# Hiperparámetros: (50, None, 2, 2, None)
# Accuracy: 0.8954, Precisión por clase: [0.89951831 0.88678326], Recall por clase: [0.94591267 0.79989902], F1 por clase: [0.92207811 0.8408983 ]
#
# Hiperparámetros: (50, None, 2, 2, 'balanced')
# Accuracy: 0.8923, Precisión por clase: [0.90228091 0.87132713], Recall por clase: [0.93690191 0.80752207], F1 por clase: [0.91923141 0.83807719]
#
# Hiperparámetros: (50, None, 5, 1, None)
# Accuracy: 0.8965, Precisión por clase: [0.90777519 0.87287953], Recall por clase: [0.93707214 0.81955197], F1 por clase: [0.9221815  0.84534455]
#
# Hiperparámetros: (50, None, 5, 1, 'balanced')
# Accuracy: 0.8956, Precisión por clase: [0.9067281  0.87262844], Recall por clase: [0.93697121 0.81730843], F1 por clase: [0.92155447 0.84388423]
#
# Hiperparámetros: (50, None, 5, 2, None)
# Accuracy: 0.8971, Precisión por clase: [0.89789264 0.89532182], Recall por clase: [0.95097719 0.79518204], F1 por clase: [0.92366777 0.84227361]
#
# Hiperparámetros: (50, None, 5, 2, 'balanced')
# Accuracy: 0.8937, Precisión por clase: [0.91140878 0.8593275 ], Recall por clase: [0.92786219 0.82921584], F1 por clase: [0.91946753 0.84366398]
#
# Hiperparámetros: (50, 10, 2, 1, None)
# Accuracy: 0.8923, Precisión por clase: [0.90617629 0.86379387], Recall por clase: [0.93210419 0.81683088], F1 por clase: [0.91891577 0.83950008]
#
# Hiperparámetros: (50, 10, 2, 1, 'balanced')
# Accuracy: 0.8964, Precisión por clase: [0.90677902 0.87451386], Recall por clase: [0.93836501 0.81692337], F1 por clase: [0.92227849 0.84465207]
#
# Hiperparámetros: (50, 10, 2, 2, None)
# Accuracy: 0.8896, Precisión por clase: [0.90266338 0.86231961], Recall por clase: [0.93192791 0.80968538], F1 por clase: [0.9170364  0.83508581]
#
# Hiperparámetros: (50, 10, 2, 2, 'balanced')
# Accuracy: 0.8907, Precisión por clase: [0.89915974 0.87224773], Recall por clase: [0.93843432 0.80015402], F1 por clase: [0.91836109 0.83458563]
#
# Hiperparámetros: (50, 10, 5, 1, None)
# Accuracy: 0.8947, Precisión por clase: [0.90352848 0.87575656], Recall por clase: [0.93959379 0.80954042], F1 por clase: [0.92119331 0.84128146]
#
# Hiperparámetros: (50, 10, 5, 1, 'balanced')
# Accuracy: 0.8947, Precisión por clase: [0.90643322 0.87069386], Recall por clase: [0.93609977 0.81659834], F1 por clase: [0.92090629 0.84232672]
#
# Hiperparámetros: (50, 10, 5, 2, None)
# Accuracy: 0.8983, Precisión por clase: [0.90409615 0.88604573], Recall por clase: [0.9450477  0.80994794], F1 por clase: [0.92402945 0.84594857]
#
# Hiperparámetros: (50, 10, 5, 2, 'balanced')
# Accuracy: 0.8940, Precisión por clase: [0.90645344 0.86795877], Recall por clase: [0.93461459 0.81709344], F1 por clase: [0.92030184 0.84170706]
#
# Hiperparámetros: (50, 20, 2, 1, None)
# Accuracy: 0.8930, Precisión por clase: [0.90728768 0.86354965], Recall por clase: [0.93177848 0.81928186], F1 por clase: [0.91936228 0.84079865]
#
# Hiperparámetros: (50, 20, 2, 1, 'balanced')
# Accuracy: 0.9056, Precisión por clase: [0.91108048 0.8945573 ], Recall por clase: [0.94863745 0.82430633], F1 por clase: [0.92939974 0.85767534]
#
# Hiperparámetros: (50, 20, 2, 2, None)
# Accuracy: 0.9021, Precisión por clase: [0.90653117 0.89329378], Recall por clase: [0.94815148 0.81475741], F1 por clase: [0.92680054 0.85191306]
#
# Hiperparámetros: (50, 20, 2, 2, 'balanced')
# Accuracy: 0.8955, Precisión por clase: [0.90509251 0.8777283 ], Recall por clase: [0.93928974 0.8125839 ], F1 por clase: [0.9216329  0.84291335]
#
# Hiperparámetros: (50, 20, 5, 1, None)
# Accuracy: 0.8938, Precisión por clase: [0.9063852  0.86802499], Recall por clase: [0.93429408 0.81690091], F1 por clase: [0.92010915 0.84160889]
#
# Hiperparámetros: (50, 20, 5, 1, 'balanced')
# Accuracy: 0.9005, Precisión por clase: [0.90721985 0.88633174], Recall por clase: [0.94469514 0.81685335], F1 por clase: [0.92551696 0.84993801]
#
# Hiperparámetros: (50, 20, 5, 2, None)
# Accuracy: 0.8989, Precisión por clase: [0.90806317 0.8795307 ], Recall por clase: [0.94073118 0.81955197], F1 por clase: [0.92410026 0.84845488]
#
# Hiperparámetros: (50, 20, 5, 2, 'balanced')
# Accuracy: 0.8988, Precisión por clase: [0.90914231 0.87834196], Recall por clase: [0.9396042  0.82175531], F1 por clase: [0.92400482 0.84863928]
#
# Hiperparámetros: (100, None, 2, 1, None)
# Accuracy: 0.8982, Precisión por clase: [0.9091136  0.87518726], Recall por clase: [0.93840747 0.82190291], F1 por clase: [0.9235204  0.84768469]
#
# Hiperparámetros: (100, None, 2, 1, 'balanced')
# Accuracy: 0.8972, Precisión por clase: [0.90189855 0.88800163], Recall por clase: [0.94609977 0.80482344], F1 por clase: [0.92335769 0.84389764]
#
# Hiperparámetros: (100, None, 2, 2, None)
# Accuracy: 0.9013, Precisión por clase: [0.90334789 0.89682631], Recall por clase: [0.95104129 0.80708944], F1 por clase: [0.92655061 0.84947692]
#
# Hiperparámetros: (100, None, 2, 2, 'balanced')
# Accuracy: 0.8956, Precisión por clase: [0.9056966  0.87467133], Recall por clase: [0.9383646  0.81444238], F1 por clase: [0.9216705  0.84320684]
#
# Hiperparámetros: (100, None, 5, 1, None)
# Accuracy: 0.8973, Precisión por clase: [0.90906639 0.87330538], Recall por clase: [0.93697641 0.82182533], F1 por clase: [0.92277537 0.84662197]
#
# Hiperparámetros: (100, None, 5, 1, 'balanced')
# Accuracy: 0.9015, Precisión por clase: [0.90868231 0.88710628], Recall por clase: [0.94488225 0.81927431], F1 por clase: [0.92631323 0.85137026]
#
# Hiperparámetros: (100, None, 5, 2, None)
# Accuracy: 0.9022, Precisión por clase: [0.90559948 0.89562299], Recall por clase: [0.94981252 0.81218393], F1 por clase: [0.92710076 0.85153717]
#
# Hiperparámetros: (100, None, 5, 2, 'balanced')
# Accuracy: 0.8999, Precisión por clase: [0.91052364 0.87809445], Recall por clase: [0.93959337 0.82444638], F1 por clase: [0.92476445 0.85017128]
#
# Hiperparámetros: (100, 10, 2, 1, None)
# Accuracy: 0.8948, Precisión por clase: [0.90656663 0.87030697], Recall por clase: [0.93581651 0.81730843], F1 por clase: [0.92092229 0.84284931]
#
# Hiperparámetros: (100, 10, 2, 1, 'balanced')
# Accuracy: 0.9006, Precisión por clase: [0.90943173 0.88243117], Recall por clase: [0.94218432 0.82190291], F1 por clase: [0.9254702 0.8509071]
#
# Hiperparámetros: (100, 10, 2, 2, None)
# Accuracy: 0.9006, Precisión por clase: [0.90250984 0.89667627], Recall por clase: [0.95106814 0.80489347], F1 por clase: [0.92610537 0.84810513]
#
# Hiperparámetros: (100, 10, 2, 2, 'balanced')
# Accuracy: 0.9014, Precisión por clase: [0.90952318 0.88512344], Recall por clase: [0.94346637 0.82192537], F1 por clase: [0.9260955  0.85200118]
#
# Hiperparámetros: (100, 10, 5, 1, None)
# Accuracy: 0.8998, Precisión por clase: [0.90622922 0.88572753], Recall por clase: [0.94478046 0.81456488], F1 por clase: [0.92508804 0.84860285]
#
# Hiperparámetros: (100, 10, 5, 1, 'balanced')
# Accuracy: 0.8998, Precisión por clase: [0.90826555 0.88291066], Recall por clase: [0.94232897 0.81930433], F1 por clase: [0.92485153 0.84939203]
#
# Hiperparámetros: (100, 10, 5, 2, None)
# Accuracy: 0.9031, Precisión por clase: [0.90269026 0.90449993], Recall por clase: [0.95494114 0.80492348], F1 por clase: [0.92801265 0.85152117]
#
# Hiperparámetros: (100, 10, 5, 2, 'balanced')
# Accuracy: 0.8932, Precisión por clase: [0.90432224 0.87087215], Recall por clase: [0.93606773 0.81228397], F1 por clase: [0.9197951  0.84007434]
#
# Hiperparámetros: (100, 20, 2, 1, None)
# Accuracy: 0.8954, Precisión por clase: [0.90449142 0.87640679], Recall por clase: [0.93947556 0.81219148], F1 por clase: [0.92161983 0.8429736 ]
#
# Hiperparámetros: (100, 20, 2, 1, 'balanced')
# Accuracy: 0.9014, Precisión por clase: [0.90245714 0.8990783 ], Recall por clase: [0.95224322 0.80487856], F1 por clase: [0.92666179 0.84929388]
#
# Hiperparámetros: (100, 20, 2, 2, None)
# Accuracy: 0.8972, Precisión por clase: [0.90381818 0.883071  ], Recall por clase: [0.94350924 0.80985545], F1 por clase: [0.92319822 0.84474189]
#
# Hiperparámetros: (100, 20, 2, 2, 'balanced')
# Accuracy: 0.8981, Precisión por clase: [0.90715017 0.88035484], Recall por clase: [0.94102007 0.81701586], F1 por clase: [0.92363564 0.84694023]
#
# Hiperparámetros: (100, 20, 5, 1, None)
# Accuracy: 0.8996, Precisión por clase: [0.90308873 0.8925104 ], Recall por clase: [0.94842349 0.80730443], F1 por clase: [0.92512449 0.84746422]
#
# Hiperparámetros: (100, 20, 5, 1, 'balanced')
# Accuracy: 0.9032, Precisión por clase: [0.9088714  0.89232409], Recall por clase: [0.94736622 0.81973695], F1 por clase: [0.9276049  0.85401249]
#
# Hiperparámetros: (100, 20, 5, 2, None)
# Accuracy: 0.9014, Precisión por clase: [0.90345763 0.89818141], Recall por clase: [0.95120155 0.8074745 ], F1 por clase: [0.92659745 0.84991521]
#
# Hiperparámetros: (100, 20, 5, 2, 'balanced')
# Accuracy: 0.8971, Precisión por clase: [0.90380112 0.88297694], Recall por clase: [0.94346637 0.80934789], F1 por clase: [0.92315663 0.84435958]
#
# Hiperparámetros: (200, None, 2, 1, None)
# Accuracy: 0.9007, Precisión por clase: [0.90843558 0.88402842], Recall por clase: [0.94345596 0.81937435], F1 por clase: [0.92559719 0.85039436]
#
# Hiperparámetros: (200, None, 2, 1, 'balanced')
# Accuracy: 0.9032, Precisión por clase: [0.90686617 0.8956211 ], Recall por clase: [0.94979692 0.81461245], F1 por clase: [0.92777616 0.85294973]
#
# Hiperparámetros: (200, None, 2, 2, None)
# Accuracy: 0.8989, Precisión por clase: [0.90410946 0.8882791 ], Recall por clase: [0.94612662 0.80973295], F1 por clase: [0.92456391 0.84688261]
#
# Hiperparámetros: (200, None, 2, 2, 'balanced')
# Accuracy: 0.9007, Precisión por clase: [0.90845681 0.88450137], Recall por clase: [0.94356252 0.81956688], F1 por clase: [0.92561267 0.85054806]
#
# Hiperparámetros: (200, None, 5, 1, None)
# Accuracy: 0.8948, Precisión por clase: [0.90257496 0.87804275], Recall por clase: [0.94094514 0.80756699], F1 por clase: [0.92134053 0.84126347]
#
# Hiperparámetros: (200, None, 5, 1, 'balanced')
# Accuracy: 0.8990, Precisión por clase: [0.90825804 0.88066014], Recall por clase: [0.94097762 0.81937435], F1 por clase: [0.92419424 0.84837434]
#
# Hiperparámetros: (200, None, 5, 2, None)
# Accuracy: 0.9008, Precisión por clase: [0.90947185 0.88245345], Recall por clase: [0.94245675 0.82192537], F1 por clase: [0.92563046 0.85096827]
#
# Hiperparámetros: (200, None, 5, 2, 'balanced')
# Accuracy: 0.8999, Precisión por clase: [0.90846355 0.88250812], Recall por clase: [0.94233375 0.81963691], F1 por clase: [0.92500073 0.84956131]
#
# Hiperparámetros: (200, 10, 2, 1, None)
# Accuracy: 0.8964, Precisión por clase: [0.90573604 0.8764053 ], Recall por clase: [0.93955611 0.81456488], F1 por clase: [0.92233039 0.84433429]
#
# Hiperparámetros: (200, 10, 2, 1, 'balanced')
# Accuracy: 0.8998, Precisión por clase: [0.90432143 0.89022315], Recall por clase: [0.94728609 0.80961045], F1 por clase: [0.9252508 0.847779 ]
#
# Hiperparámetros: (200, 10, 2, 2, None)
# Accuracy: 0.9021, Precisión por clase: [0.90441315 0.89760808], Recall por clase: [0.95101444 0.80966292], F1 por clase: [0.92705802 0.8510847 ]
#
# Hiperparámetros: (200, 10, 2, 2, 'balanced')
# Accuracy: 0.8990, Precisión por clase: [0.908224   0.87977159], Recall por clase: [0.94090227 0.81954442], F1 por clase: [0.92422642 0.8484071 ]
#
# Hiperparámetros: (200, 10, 5, 1, None)
# Accuracy: 0.8990, Precisión por clase: [0.90615071 0.8835909 ], Recall por clase: [0.94337583 0.81473495], F1 por clase: [0.92438581 0.84774924]
#
# Hiperparámetros: (200, 10, 5, 1, 'balanced')
# Accuracy: 0.9007, Precisión por clase: [0.90651872 0.88853769], Recall por clase: [0.94611102 0.81444238], F1 por clase: [0.92581813 0.84957119]
#
# Hiperparámetros: (200, 10, 5, 2, None)
# Accuracy: 0.9005, Precisión por clase: [0.90523682 0.89068142], Recall por clase: [0.94722157 0.8121139 ], F1 por clase: [0.92568278 0.8493043 ]
#
# Hiperparámetros: (200, 10, 5, 2, 'balanced')
# Accuracy: 0.8999, Precisión por clase: [0.90833422 0.88208044], Recall por clase: [0.94225362 0.81954442], F1 por clase: [0.92493918 0.84949842]
#
# Hiperparámetros: (200, 20, 2, 1, None)
# Accuracy: 0.8981, Precisión por clase: [0.90208891 0.88967028], Recall por clase: [0.94716829 0.80518604], F1 por clase: [0.92402785 0.84511774]
#
# Hiperparámetros: (200, 20, 2, 1, 'balanced')
# Accuracy: 0.9006, Precisión por clase: [0.90242778 0.89716062], Recall por clase: [0.95116387 0.80497105], F1 por clase: [0.92609943 0.84834282]
#
# Hiperparámetros: (200, 20, 2, 2, None)
# Accuracy: 0.9023, Precisión por clase: [0.90757472 0.89177549], Recall por clase: [0.94743552 0.81721594], F1 por clase: [0.92698401 0.85250127]
#
# Hiperparámetros: (200, 20, 2, 2, 'balanced')
# Accuracy: 0.9007, Precisión por clase: [0.90848051 0.88513796], Recall por clase: [0.94357335 0.81956688], F1 por clase: [0.92557791 0.8506186 ]
#
# Hiperparámetros: (200, 20, 5, 1, None)
# Accuracy: 0.8974, Precisión por clase: [0.90499427 0.88128406], Recall por clase: [0.94235019 0.8119914 ], F1 por clase: [0.9232561  0.84504143]
#
# Hiperparámetros: (200, 20, 5, 1, 'balanced')
# Accuracy: 0.9015, Precisión por clase: [0.9065946  0.89122866], Recall por clase: [0.94736622 0.81444238], F1 por clase: [0.92643473 0.85070061]
#
# Hiperparámetros: (200, 20, 5, 2, None)
# Accuracy: 0.8988, Precisión por clase: [0.90403841 0.88847776], Recall por clase: [0.94612662 0.80968538], F1 por clase: [0.92448083 0.84676075]
#
# Hiperparámetros: (200, 20, 5, 2, 'balanced')
# Accuracy: 0.9023, Precisión por clase: [0.90670391 0.89307591], Recall por clase: [0.94855732 0.81463491], F1 por clase: [0.92710566 0.8518377 ]
#
# Mejores hiperparámetros para window_3s_overlapped: (50, 20, 2, 1, 'balanced'), Mejor F1 promedio: 0.8935
#
# Resumen de los mejores hiperparámetros por dataset:
# window_10s: {'best_params': (100, 10, 2, 1, 'balanced'), 'best_score': 0.876585141304844}
# window_5s: {'best_params': (200, 10, 5, 1, 'balanced'), 'best_score': 0.9202128536278118}
# window_3s: {'best_params': (200, 10, 2, 1, None), 'best_score': 0.8858893927995746}
# window_1s: {'best_params': (200, 10, 2, 2, None), 'best_score': 0.8768116673977445}
# window_10s_overlapped: {'best_params': (100, 10, 2, 1, None), 'best_score': 0.8835318114581967}
# window_5s_overlapped: {'best_params': (200, 10, 2, 2, None), 'best_score': 0.8960621896217594}
# window_3s_overlapped: {'best_params': (50, 20, 2, 1, 'balanced'), 'best_score': 0.8935375403671808}

# %% [markdown]
# Para cada modelo generado durante la validación cruzada, obtenemos métricas como el `accuracy` y métricas más apropiadas para problemas desbalanceados, tales como `precisión`, `recall` y `f1-score`. La métrica utilizada para seleccionar el mejor modelo es el **f1-score**, ya que combina tanto la precisión como el recall, proporcionando una evaluación más equilibrada del rendimiento del modelo en este tipo de problemas.
#
# En cuanto a los resultados obtenidos de la validación cruzada, podemos destacar los siguientes aspectos:
#
# 1. **Mejor rendimiento general**: El mejor f1-score se obtiene con la ventana de 5 segundos sin solapamiento (window_5s), con un valor de **0.9202**.
# Esto sugiere que una ventana de 5 segundos captura suficiente información para la clasificación sin necesidad de solapamiento.
#
# 2. **Efecto del solapamiento**: En general, el solapamiento no siempre mejora el rendimiento. Por ejemplo, para ventanas solapadas de 10 segundos (0.8835), se obtiene un resultado extremadamente similar al modelo entrenado con el mismo tamaño de ventana sin solapamiento (0.8766), lo que indica que solapar en esta configuración no aporta una mejora significativa. De hecho, el mejor modelo obtenido (mayor f1-score) se corresponde a un conjunto de datos sin solapamiento.
#
# 3. **Importancia de los hiperparámetros**:
#   - Los mejores resultados suelen darse con `n_estimators = 200`, lo que indica que un mayor número de árboles en el modelo RandomForest mejora la estabilidad.
#
#   - Por otro lado `max_depth` se mantiene en valores de 10 (menos uno de 20), sugiriendo que una profundidad intermedia es adecuada para evitar sobreajuste.
#
#   - En cuanto a `min_samples_split` y `min_samples_leaf`, no podemos extraer información muy relevante ya que sus valores varían entre configuraciones y no hemos explorado un rango amplio de opciones en la optimización de hiperparámetros.
#
#   - El parámetro `class_weight` varía entre 'balanced' y None. En algunos casos, usar 'balanced' mejora el rendimiento, como en window_5s, pero en otros no es necesario.

# %% [markdown]
# ## **6. Construcción del mejor modelo y evaluación sobre el conjunto de test**

# %% [markdown]
# Basándonos en los resultados obtenidos durante la validación cruzada, el mejor modelo (mayor f-score) es el que consta de los siguientes hiperparámetros:
#
# - **n_estimators**: 200
#
# - **max_depth**: 10
#
# - **min_sample_split**: 5
#
# - **min_samples_leaf**: 1
#
# - **class_weight**: balanced
#
# Además, los mejores resultados son los que utilizan una **ventana de 5 segundos sin solapamiento**.

# %% [markdown]
# Para evaluar nuestro modelo con los datos de prueba, es necesario que estos también estén transformados en ventanas temporales. Por ello, generamos el conjunto de datos de prueba utilizando ventanas deslizantes de 5 segundos sin solapamiento.

# %%
test_stopping_data_window = generate_sliding_windows(test_stopping_data, window_seconds=5, overlap_seconds=0)

# %% [markdown]
# Entrenamos el modelo con todos los datos de entrenamiento (los 4 conductores) y lo evaluamos con los datos de prueba (el conductor número 5).

# %%
# Separamos características y etiquetas
X_train = train_stopping_data_window_5s.drop(columns=['Maneuver_marker', 'Driver'])
y_train = train_stopping_data_window_5s['Maneuver_marker']
X_test = test_stopping_data_window.drop(columns=['Maneuver_marker', 'Driver'])
y_test = test_stopping_data_window ['Maneuver_marker']

# Guardamos los nombres de las características antes de la normalización
feature_names = X_train.columns

# Normalizamos SOLO con datos de entrenamiento
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Entrenamos el modelo con los hiperparámetros actuales
model = RandomForestClassifier(n_estimators=100, max_depth=None,
                                min_samples_split=5, min_samples_leaf=1, class_weight='balanced')
model.fit(X_train, y_train)

# Realizamos predicciones
y_pred = model.predict(X_test)
# Calculamos métricas
print("Accuracy: ", accuracy_score(y_test, y_pred))
print("Precision: ", precision_score(y_test, y_pred, average=None))  # Por clase
print("Recall: ", recall_score(y_test, y_pred, average=None))
print("F1_score: ", f1_score(y_test, y_pred, average=None))
# Out:
# Accuracy:  0.9217391304347826
# Precision:  [0.91666667 0.93023256]
# Recall:  [0.95652174 0.86956522]
# F1_score:  [0.93617021 0.8988764 ]

# %% [markdown]
# ## **7. Análisis de resultados**

# %% [markdown]
# Analizando los resultados obtenidos, el modelo muestra un buen desempeño general con un **accuracy** del **92.17%**, indicando que clasifica correctamente la mayoría de los casos. La **precisión** es alta en ambas clases (91.67% para "No-Frenado" y 93.02% para "Frenado"), mientras que el **recall** es ligeramente menor para la clase "Frenado" (86.96% frente a 95.65% en "No-Frenado"), lo que sugiere que algunos casos de frenado no se detectan correctamente.
#
# Esto lo podemos observar más claramente en la siguiente matriz de confusión:

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["No-Frenado", "Frenado"], yticklabels=["No-Frenado", "Frenado"])
plt.xlabel("Predicción")
plt.ylabel("Real")
plt.title("Matriz de Confusión")
plt.show()

# %% [markdown]
# ### **7.1 Explicabilidad del modelo**

# %% [markdown]
# El modelo RandomForest nos permite investigar la **relevancia de las características** utilizadas en el proceso de toma de decisiones, mediante el cálculo de la importancia de los atributos.
#
# Este cálculo se realiza de manera interna, utilizando un criterio heurístico que selecciona los atributos que contribuyen más a la reducción de la **entropía** a lo largo de los árboles del bosque (estos atributos pueden aparecer en diferentes ubicaciones dentro de un mismo árbol o en distintos árboles).
#
# Es importante destacar que la importancia asignada a un atributo refleja su utilidad para el modelo, pero no necesariamente significa que los atributos con menor importancia no sean relevantes para el problema en sí.

# %%
# Convertimos X_train a DataFrame después de la normalización
X_train_df = pd.DataFrame(X_train, columns=feature_names)

# Ahora podemos acceder a las columnas de forma correcta
importances = model.feature_importances_
feature_names = X_train_df.columns

# Ordenar características por importancia
sorted_indices = np.argsort(importances)[::-1]

# Limitar a las 100 características más importantes
top_n = 100
sorted_indices = sorted_indices[:top_n]
importances_top = importances[sorted_indices]
feature_names_top = [feature_names[i] for i in sorted_indices]

# Crear la gráfica
plt.figure(figsize=(25, 15))
plt.bar(range(top_n), importances_top, align="center")
plt.xticks(range(top_n), feature_names_top, rotation=90)
plt.xlabel("Características")
plt.ylabel("Importancia")
plt.title(f"Top {top_n} Características en RandomForest")
plt.show()

# %% [markdown]
# La gráfica muestra la importancia relativa de las **100 características más relevantes** en el modelo RandomForest utilizado para la clasificación de la **maniobra de frenado**. Se observa que la característica más influyente es **Gas pedal_mean_5s**, destacándose significativamente sobre el resto, lo que indica que la variación promedio del pedal del acelerador en los últimos 5 segundos tiene un fuerte impacto en la predicción de frenado.
#
# Después de esta, otras características relacionadas con la posición del pedal del gas, como **Gas pedal_183, Gas pedal_t97, Gas pedal_t92 y Gas pedal_t82**, también tienen una alta importancia, lo que sugiere que la manera en que el conductor modula el acelerador es clave para determinar si está frenando. Además, varias características relacionadas con el pedal de freno (`Brake pedal`) aparecen en posiciones destacadas, lo que era esperable dado que el frenado es el evento de interés.
#
# Otras variables, como las **RPM**, la velocidad (**Speed**) y el pedal de embrague (**Clutch pedal**), tienen menor peso en la clasificación, pero aún aportan información relevante.
#
# La distribución de la importancia sugiere que hay un conjunto de características principales con una fuerte influencia, seguidas por muchas otras con una contribución más moderada. Esto indica que el modelo se basa principalmente en unas pocas variables clave, aunque considera múltiples aspectos del comportamiento del vehículo para tomar decisiones.

# %% [markdown]
# ## **8. Comparación entre ambos modelos (Stopping y Overtaking)**
# A continuación, se analizarán y compararán los dos modelos desarrollados, cada uno diseñado para clasificar una maniobra específica:
#
# 1. **Rendimiento General**
#   - El modelo de frenado obtuvo un mejor rendimiento global en comparación con el modelo de adelantamiento. Su mejor configuración alcanzó un f1-score de 0.9202 y una exactitud del 92.17%, mientras que el modelo de adelantamiento logró un f1-score de 0.8408 y una exactitud del 85.4%.
#
#   - Esto sugiere que la maniobra de frenado es más fácil de clasificar con las características disponibles en los datos, posiblemente debido a que el frenado genera patrones más evidentes en variables como el pedal del acelerador y el freno, mientras que la maniobra de adelantamiento puede depender de factores más sutiles y variables adicionales, como la posición en el carril.
#
# 2. **Ventanas deslizantes**
#
#   - **Frenado**: La mejor ventana deslizante para la clasificación fue de 5 segundos sin solapamiento, lo que indica que un historial de 5 segundos es suficiente para capturar la dinámica del frenado sin necesidad de superposición.
#
#   - **Adelantamiento**: En este caso, la mejor configuración correspondió a una ventana mucho más corta, de 1 segundo sin solapamiento, lo que sugiere que la información relevante para detectar un adelantamiento se encuentra en un período más breve, ya que como explicaremos después el modelo se basa fundamentalmente en la posición del vehículo.
#
#   Esto refleja una diferencia clave en la naturaleza de ambas maniobras: el frenado es un proceso más progresivo que puede durar varios segundos, mientras que el adelantamiento es una acción más rápida, donde la posición del vehículo es un factor determinantes.
#
# 3. **Precisión y Recall por Clase**
#
#   - **Frenado**:
#
#     - Precisión alta en ambas clases: 91.67% para "No-Frenado" y 93.02% para "Frenado".
#
#     - Recall menor en la clase Frenado (86.96%), indicando que algunos eventos de frenado no se detectan correctamente.
#
#   - **Adelantamiento**:
#
#     - Precisión alta para la clase "Adelantamiento" (97.8%), lo que significa que el modelo rara vez clasifica erróneamente otras maniobras como adelantamientos.
#
#     - Recall más bajo en la clase "Adelantamiento" (76%), lo que indica que el modelo omite algunos adelantamientos reales, priorizando la detección de "No-Adelantamiento".
#
#   En términos generales, el modelo de frenado muestra un equilibrio más uniforme entre precisión y recall en ambas clases, mientras que el modelo de adelantamiento tiene un sesgo hacia la detección de "No-Adelantamiento", con una menor sensibilidad para capturar todos los adelantamientos reales.
#
# 4. **Importancia de las Características**
#
#   - **Frenado**: Las variables más influyentes están relacionadas con el pedal del acelerador y el pedal de freno, destacando Gas pedal_mean_5s como la característica más relevante. Esto confirma que la modulación del acelerador es clave para detectar frenadas.
#
#   - **Adelantamiento**: La característica más influyente es Lat Pos, que refleja la posición del vehículo, lo que es esperable dado que un adelantamiento implica un cambio de carril. También aparecen variables como elapsed_time y speed, indicando que la velocidad y el tiempo transcurrido juegan un papel importante.
#
#   En el modelo de frenado, unas pocas variables clave dominan la clasificación, mientras que en el modelo de adelantamiento hay una mayor dispersión en la importancia de las características, lo que sugiere que esta maniobra depende de un conjunto más diverso de factores.
#
# 5. **Hiperparámetros Óptimos**
#
#   Los modelos difieren en la configuración óptima de hiperparámetros:
#
#   - **Frenado**:
#     n_estimators = 200, max_depth = 10, min_samples_split = 5, min_samples_leaf = 1, class_weight = balanced.
#     Se observa que profundidades intermedias y un número elevado de árboles mejoran la estabilidad del modelo.
#
#   - **Adelantamiento**: n_estimators = 50, max_depth = None, min_samples_split = 5, min_samples_leaf = 1, class_weight = None. La falta de restricción en la profundidad de los árboles sugiere que el modelo requiere estructuras más complejas para capturar la variabilidad de la maniobra de adelantamiento.

# %% [markdown]
# ## **9. Conclusiones**

# %% [markdown]
# En conclusión, el modelo de frenado obtuvo mejores resultados al utilizar ventanas deslizantes de 5 segundos sin solapamiento, lo que permitió capturar de manera efectiva la dinámica de la maniobra. Además, se ha evidenciado la importancia del preprocesamiento de datos, eliminando columnas innecesarias, redundantes o constantes que no aportaban valor al modelo. A lo largo del estudio, se aplicó validación cruzada con distintos hiperparámetros y conjuntos de datos correspondientes a diferentes ventanas temporales, observando que los resultados se mantenían relativamente estables. También comprobamos que el hiperparámetro class_weight no resultó ser determinante para este problema. En cuanto a la importancia de las características, el modelo se basó principalmente en el pedal del acelerador para la detección del frenado, aunque también consideró otras variables como las revoluciones por minuto y la velocidad.
#
# Comparado con el modelo de adelantamiento, el modelo de frenado mostró un rendimiento superior, con una mejor capacidad de generalización y un equilibrio más adecuado entre precisión y recall. Esto sugiere que la detección del frenado es un problema más estructurado, con patrones más claros en los datos, mientras que la identificación de adelantamientos es más compleja debido a su dependencia de múltiples factores.
